# %%
import numpy as np
import matplotlib.pyplot as plt 
import random                          # crear numeros aleatoriamente
import scipy.io as sio
from sklearn.model_selection import train_test_split

# %%
# cargar el archivo .mat
data = sio.loadmat('Tiosulfatosodio.mat')

#Extrayendo matriz de caracteristicas 
Xi = data['x']

#Extrayendo dato esperado (Clases)
Yi = data['y']

#Agregando el bias a las filas de la matriz de caracteristicas (Entradas)
bias = np.full((Xi.shape[0], 1), 1)
Xi = np.hstack((bias, Xi))

#numero de datos
num_datos = Xi.shape[0]

#numero de caracteristicas
caract = Xi.shape[1]-1                  # Se resta el bias 

#Obteniendo datos de entrenamiento y prueba
D_entre = int(num_datos*0.9)        # datos de entrenamiento   (verificar la cantidad de dtos para hacer la particion)
D_prueba = int(num_datos*0.1)            # datos de prueba

#Vector de errores



#Definicion de errores
Err_entr = 10;
Err_pru = 10;

X_ent, X_pru, Y_ent, Y_pru = train_test_split(Xi, Yi, test_size=0.1)

# %%
import matplotlib.pyplot as plt

# Crear la figura y los subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

# Graficar la segunda gráfica en el segundo subplot
ax1.scatter(Xi[:, 1], Xi[:, 2], c=Yi, cmap=plt.cm.coolwarm)
ax1.set_title('Datos Originales')
ax1.set_xlabel("X1")
ax1.set_ylabel("X2")

# Graficar la primera gráfica en el primer subplot
ax2.scatter(X_ent[:, 1], X_ent[:, 2], c=Y_ent, cmap=plt.cm.coolwarm)
ax2.set_title('Datos de Entrenamiento')
ax2.set_xlabel("X1")
ax2.set_ylabel("X2")


# Mostrar la figura
plt.show()

# %%
#Definicion de los pesos e inicialización 
Wk = []  
for i in range(Xi.shape[1]):                      # ciclo para agregar los numeros aleatorios con los que se inicializaran los pesos
    Wk.append(random.uniform(0,1))                # vector de pesos extendido
print(Wk)
# Out:
# [0.0899049047796403, 0.9920877982529387, 0.9009642621620012]

# %%
def error_entrenamiento(x,y,w,n) -> float:
    suma = 0
    vec_Ent  = []
    
    for i in range (n):
        g = np.dot(np.transpose(w), x[i])

        if g < 0:                # se establece un umbral para poder hacer clasificacion con el algoritmo LMS
            g = -1
        else:
            g = 1

        if g != y[i]:                   # Condicion de Error
            suma = suma + 1          # contador de errores

        error_pct = 100.0 * suma / n
        vec_Ent.append(error_pct)
    
    return error_pct, vec_Ent

# %%
def error_prueba(x,y,w,n) -> float:
    suma = 0
    vec_Pru  = []
    
    for i in range (n):
        g = np.dot(np.transpose(w), x[i])

        if g < 0:                # se establece un umbral para poder hacer clasificacion con el algoritmo LMS
            g = -1
        else:
            g = 1

        if g != y[i]:                   # Condicion de Error
            suma = suma + 1          # contador de errores

        error_pct = 100.0 * suma / n
        vec_Pru.append(error_pct)
    
    return error_pct, vec_Pru

# %%
error = []
error1 = []
e = 0
N=0
u=0.1
suma=0
iteraciones = 0
Emin = 20
Eent =  0
print("Wo: ", Wk )

u = 0.1
gamma = 1.05
beta =  1.04
alpha = 0.7

V_errorEnt = []
V_errorPru = []


while( (iteraciones<2000)):

    ################## Error de entrenamiento  ###########################
    
    i = np.random.randint(0,X_ent.shape[0])#Xi.shape[0])
    print("iteraciones =",iteraciones,"\n")
    Y = Y_ent[i][0]
    g = np.dot(np.transpose(Wk),X_ent[i]) #Funcion interna de la neurona. matmul permite multiplicar dos matrices
    print("g: ", g)
    e = (g - Y)  #Error entre la salida dada y la salida esperada 
    print("error:",e)
    
    error.append(e)
    
    ########################################################################
   
    if( (error[iteraciones]/error[iteraciones-1])>beta):
        u = u*alpha
    elif(error[iteraciones]<error[iteraciones-1]):
        u = u*gamma
    
    print("Peso Wk: ", Wk , "\n")
    Wk = Wk - e*u*X_ent[i] #np.dot(value,Xi[i]) #Encuentro los nuevos valores de los pesos utilziando np.dot para multiplicar const * matriz
    
    iteraciones = iteraciones + 1;

    Eent , V_errorEnt  = error_entrenamiento(X_ent,Y_ent,Wk,D_entre)
    print("Error de entrenamiento: ", Eent )
    Epru , V_errorPru = error_prueba(X_pru,Y_pru,Wk,D_prueba)
    print("Error de Prueba: ",  Epru )
# Out:
# Wo:  [0.0899049047796403, 0.9920877982529387, 0.9009642621620012]
# iteraciones = 0
#
# g:  8.542623409787065
# error: 9.542623409787065
# Peso Wk:  [0.0899049047796403, 0.9920877982529387, 0.9009642621620012]
#
# Error de entrenamiento:  46.388888888888886
# Error de Prueba:  47.5
# iteraciones = 1
#
# g:  -8.347112671364219
# error: -9.347112671364219
# Peso Wk:  [-0.86435744 -3.32123687 -3.30221486]
#
# Error de entrenamiento:  44.44444444444444
# Error de Prueba:  47.5
# iteraciones = 2
#
# g:  -3.8882496731541574
# error: -4.888249673154157
# Peso Wk:  [ 0.11708939 -2.48827659 -1.9160337 ]
#
# Error de entrenamiento:  43.333333333333336
# Error de Prueba:  47.5
# iteraciones = 3
#
# g:  -11.73356004581477
# error: -10.73356004581477
# Peso Wk:  [ 0.63035561 -2.01959235 -1.45174688]
#
# Error de entrenamiento:  50.833333333333336
# Error de Prueba:  47.5
# iteraciones = 4
#
# g:  4.415171209652687
# error: 5.415171209652687
# Peso Wk:  [1.41927227 0.6666098  1.53022322]
#
# Error de entrenamiento:  51.666666666666664
# Error de Prueba:  47.5
# iteraciones = 5
#
# g:  0.9379131071649751
# error: -0.06208689283502489
# Peso Wk:  [ 1.02125719 -0.05233875  1.06417695]
#
# Error de entrenamiento:  51.666666666666664
# Error de Prueba:  47.5
# iteraciones = 6
#
# g:  2.7143280237375627
# error: 1.7143280237375627
# Peso Wk:  [ 1.02604875 -0.05198122  1.06381927]
#
# Error de entrenamiento:  51.388888888888886
# Error de Prueba:  47.5
# iteraciones = 7
#
# g:  4.201964860382002
# error: 5.201964860382002
# Peso Wk:  [ 0.89374548 -0.01296506  0.85576067]
#
# Error de entrenamiento:  36.666666666666664
# Error de Prueba:  40.0
# iteraciones = 8
#
# g:  0.10053825217076734
# error: -0.8994617478292326
# Peso Wk:  [ 0.61272233 -1.1935781  -0.2485118 ]
#
# Error de entrenamiento:  34.44444444444444
# Error de Prueba:  40.0
# iteraciones = 9
#
# g:  -0.22881851486693533
# error: -1.2288185148669353
# Peso Wk:  [ 0.66374306 -1.19188023 -0.15151248]
#
# Error de entrenamiento:  34.44444444444444
# Error de Prueba:  37.5
# iteraciones = 10
#
# g:  -0.8542926882129042
# error: -1.854292688212904
# Peso Wk:  [ 0.71253519 -1.15365409 -0.16478536]
#
# Error de entrenamiento:  33.611111111111114
# Error de Prueba:  37.5
# iteraciones = 11
#
# g:  -2.0593653403346956
# error: -1.0593653403346956
# Peso Wk:  [ 0.76407447 -1.08323742 -0.16771829]
#
# Error de entrenamiento:  31.11111111111111
# Error de Prueba:  37.5
# iteraciones = 12
#
# g:  -2.6762182797372915
# error: -1.6762182797372915
# Peso Wk:  [ 0.79351908 -1.02101536 -0.07390727]
#
# Error de entrenamiento:  26.944444444444443
# Error de Prueba:  35.0
# iteraciones = 13
#
# g:  -0.6973054612050013
# error: 0.30269453879499875
# Peso Wk:  [ 0.82613193 -0.92002822  0.06205474]
#
# Error de entrenamiento:  28.055555555555557
# Error de Prueba:  35.0
# iteraciones = 14
#
# g:  -0.30978816350873395
# error: -1.3097881635087338
# Peso Wk:  [ 0.82024264 -0.9312953   0.03958952]
#
# Error de entrenamiento:  26.38888888888889
# Error de Prueba:  35.0
# iteraciones = 15
#
# g:  0.3128518247160341
# error: -0.6871481752839659
# Peso Wk:  [ 0.84700032 -0.89920319  0.03075441]
#
# Error de entrenamiento:  25.27777777777778
# Error de Prueba:  32.5
# iteraciones = 16
#
# g:  -3.546410643417164
# error: -2.546410643417164
# Peso Wk:  [ 0.86103808 -0.88970263  0.06472313]
#
# Error de entrenamiento:  22.5
# Error de Prueba:  32.5
# iteraciones = 17
#
# g:  -0.20219813410028142
# error: 0.7978018658997186
# Peso Wk:  [ 0.89745254 -0.69841998  0.21443481]
#
# Error de entrenamiento:  21.11111111111111
# Error de Prueba:  27.5
# iteraciones = 18
#
# g:  -0.12439919526526919
# error: -1.1243991952652692
# Peso Wk:  [ 0.88604373 -0.72362837  0.19083634]
#
# Error de entrenamiento:  21.11111111111111
# Error de Prueba:  32.5
# iteraciones = 19
#
# g:  -0.19982379517573692
# error: -1.199823795175737
# Peso Wk:  [ 0.90292695 -0.70004797  0.19085687]
#
# Error de entrenamiento:  21.944444444444443
# Error de Prueba:  30.0
# iteraciones = 20
#
# g:  -1.1070780661040955
# error: -0.10707806610409554
# Peso Wk:  [ 0.91553797 -0.67718729  0.20184291]
#
# Error de entrenamiento:  22.5
# Error de Prueba:  30.0
# iteraciones = 21
#
# g:  1.0900073158270793
# error: 0.09000731582707933
# Peso Wk:  [ 0.91666344 -0.67285231  0.20510885]
#
# Error de entrenamiento:  22.22222222222222
# Error de Prueba:  30.0
# iteraciones = 22
#
# g:  -0.19362513667568332
# error: -1.1936251366756834
# Peso Wk:  [ 0.91571739 -0.67313468  0.203383  ]
#
# Error de entrenamiento:  22.22222222222222
# Error de Prueba:  27.5
# iteraciones = 23
#
# g:  -0.10656728380824299
# error: 0.893432716191757
# Peso Wk:  [ 0.92889055 -0.65290217  0.19849398]
#
# Error de entrenamiento:  20.0
# Error de Prueba:  30.0
# iteraciones = 24
#
# g:  -1.218298723728853
# error: -0.21829872372885295
# Peso Wk:  [ 0.9190304  -0.67886336  0.16453658]
#
# Error de entrenamiento:  20.833333333333332
# Error de Prueba:  30.0
# iteraciones = 25
#
# g:  -0.42474115329770173
# error: 0.5752588467022983
# Peso Wk:  [ 0.92156006 -0.66911982  0.17187728]
#
# Error de entrenamiento:  20.0
# Error de Prueba:  25.0
# iteraciones = 26
#
# g:  -0.8183199453342702
# error: 0.18168005466572978
# Peso Wk:  [ 0.91489391 -0.68599345  0.15840346]
#
# Error de entrenamiento:  20.27777777777778
# Error de Prueba:  27.5
# iteraciones = 27
#
# g:  -0.04788448619961874
# error: -1.0478844861996188
# Peso Wk:  [ 0.91268333 -0.69242003  0.15475978]
#
# Error de entrenamiento:  20.555555555555557
# Error de Prueba:  30.0
# iteraciones = 28
#
# g:  -1.9793125874116642
# error: -0.9793125874116642
# Peso Wk:  [ 0.92607095 -0.670753    0.16860684]
#
# Error de entrenamiento:  24.166666666666668
# Error de Prueba:  27.5
# iteraciones = 29
#
# g:  0.9182061669059776
# error: -0.08179383309402244
# Peso Wk:  [ 0.9385825  -0.60826707  0.20159338]
#
# Error de entrenamiento:  24.166666666666668
# Error de Prueba:  27.5
# iteraciones = 30
#
# g:  -0.6676441783213243
# error: 0.3323558216786757
# Peso Wk:  [ 0.93962749 -0.60790125  0.20259157]
#
# Error de entrenamiento:  21.38888888888889
# Error de Prueba:  27.5
# iteraciones = 31
#
# g:  0.4637381028901997
# error: 1.4637381028901997
# Peso Wk:  [ 0.93538136 -0.62457292  0.18625305]
#
# Error de entrenamiento:  17.77777777777778
# Error de Prueba:  25.0
# iteraciones = 32
#
# g:  -0.8238826094219649
# error: 0.1761173905780351
# Peso Wk:  [ 0.922291   -0.64950917  0.13578122]
#
# Error de entrenamiento:  17.77777777777778
# Error de Prueba:  25.0
# iteraciones = 33
#
# g:  -0.3539469897637266
# error: 0.6460530102362734
# Peso Wk:  [ 0.92063722 -0.65502178  0.13067971]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  22.5
# iteraciones = 34
#
# g:  -0.46853120488387495
# error: -1.468531204883875
# Peso Wk:  [ 0.9163906  -0.66620287  0.11605478]
#
# Error de entrenamiento:  17.5
# Error de Prueba:  25.0
# iteraciones = 35
#
# g:  -0.10086815972889174
# error: 0.8991318402711083
# Peso Wk:  [ 0.92652616 -0.64224956  0.1326056 ]
#
# Error de entrenamiento:  18.055555555555557
# Error de Prueba:  22.5
# iteraciones = 36
#
# g:  -1.0117668890601772
# error: -0.0117668890601772
# Peso Wk:  [ 0.9203205  -0.6562452   0.11290032]
#
# Error de entrenamiento:  18.055555555555557
# Error de Prueba:  22.5
# iteraciones = 37
#
# g:  -0.8268018062049582
# error: 0.17319819379504175
# Peso Wk:  [ 0.92040577 -0.65596541  0.1130673 ]
#
# Error de entrenamiento:  18.333333333333332
# Error de Prueba:  22.5
# iteraciones = 38
#
# g:  -0.07390314752166463
# error: -1.0739031475216647
# Peso Wk:  [ 0.91915062 -0.65946154  0.11217999]
#
# Error de entrenamiento:  17.77777777777778
# Error de Prueba:  25.0
# iteraciones = 39
#
# g:  -1.392391927058172
# error: -0.39239192705817194
# Peso Wk:  [ 0.92732224 -0.64425528  0.12923368]
#
# Error de entrenamiento:  18.333333333333332
# Error de Prueba:  30.0
# iteraciones = 40
#
# g:  -0.4583704506724735
# error: -1.4583704506724735
# Peso Wk:  [ 0.93030806 -0.63215245  0.13597395]
#
# Error de entrenamiento:  19.444444444444443
# Error de Prueba:  27.5
# iteraciones = 41
#
# g:  -0.33122971593953765
# error: 0.6687702840604623
# Peso Wk:  [ 0.93807606 -0.61361438  0.14282552]
#
# Error de entrenamiento:  17.5
# Error de Prueba:  30.0
# iteraciones = 42
#
# g:  -0.41717627497242044
# error: 0.5828237250275796
# Peso Wk:  [ 0.93451386 -0.62433984  0.12840387]
#
# Error de entrenamiento:  17.5
# Error de Prueba:  25.0
# iteraciones = 43
#
# g:  -0.499746834878716
# error: 0.500253165121284
# Peso Wk:  [ 0.93125423 -0.63336327  0.11884279]
#
# Error de entrenamiento:  17.5
# Error de Prueba:  25.0
# iteraciones = 44
#
# g:  -1.5966251182773326
# error: -0.5966251182773326
# Peso Wk:  [ 0.92831651 -0.64067378  0.1152554 ]
#
# Error de entrenamiento:  17.22222222222222
# Error de Prueba:  30.0
# iteraciones = 45
#
# g:  0.35353735315709955
# error: -0.6464626468429004
# Peso Wk:  [ 0.93199535 -0.62450562  0.12453623]
#
# Error de entrenamiento:  18.055555555555557
# Error de Prueba:  30.0
# iteraciones = 46
#
# g:  0.06806291445674974
# error: -0.9319370855432503
# Peso Wk:  [ 0.93478565 -0.62067456  0.13078698]
#
# Error de entrenamiento:  18.61111111111111
# Error de Prueba:  27.5
# iteraciones = 47
#
# g:  0.59889500832634
# error: -0.40110499167366
# Peso Wk:  [ 0.93760139 -0.61674189  0.1307904 ]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 48
#
# g:  0.7096501166901603
# error: -0.2903498833098397
# Peso Wk:  [ 0.93881328 -0.61571335  0.13250206]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 49
#
# g:  -0.33300680203576605
# error: -1.333006802035766
# Peso Wk:  [ 0.93969053 -0.61500912  0.13425728]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 50
#
# g:  1.2019746994731564
# error: 0.20197469947315638
# Peso Wk:  [ 0.9425098  -0.60981397  0.13133005]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 51
#
# g:  -0.41500202586667934
# error: 0.5849979741333207
# Peso Wk:  [ 0.94208263 -0.60967967  0.13110969]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 52
#
# g:  -1.5302945417362241
# error: -0.5302945417362241
# Peso Wk:  [ 0.94121655 -0.6118349   0.13005208]
#
# Error de entrenamiento:  19.166666666666668
# Error de Prueba:  27.5
# iteraciones = 53
#
# g:  0.3044569590387847
# error: -0.6955430409612153
# Peso Wk:  [ 0.9420409  -0.60783954  0.1331826 ]
#
# Error de entrenamiento:  19.166666666666668
# Error de Prueba:  27.5
# iteraciones = 54
#
# g:  0.5032502160282158
# error: -0.49674978397178415
# Peso Wk:  [ 0.94279775 -0.60684842  0.13408274]
#
# Error de entrenamiento:  19.166666666666668
# Error de Prueba:  27.5
# iteraciones = 55
#
# g:  0.9800956491756333
# error: -0.0199043508243667
# Peso Wk:  [ 0.94333829 -0.60654312  0.1336925 ]
#
# Error de entrenamiento:  19.166666666666668
# Error de Prueba:  27.5
# iteraciones = 56
#
# g:  -0.15021588278768827
# error: 0.8497841172123117
# Peso Wk:  [ 0.94335995 -0.60654484  0.13369064]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 57
#
# g:  0.29834600876951833
# error: -0.7016539912304817
# Peso Wk:  [ 0.94243526 -0.60919955  0.12921032]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 58
#
# g:  -0.2097128643165927
# error: 0.7902871356834074
# Peso Wk:  [ 0.94323694 -0.60814973  0.13016378]
#
# Error de entrenamiento:  18.61111111111111
# Error de Prueba:  27.5
# iteraciones = 59
#
# g:  -0.06485195113006542
# error: -1.0648519511300654
# Peso Wk:  [ 0.94233399 -0.61052714  0.12705412]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 60
#
# g:  -0.09418169924894008
# error: -1.0941816992489402
# Peso Wk:  [ 0.94361147 -0.60790546  0.12952501]
#
# Error de entrenamiento:  19.166666666666668
# Error de Prueba:  27.5
# iteraciones = 61
#
# g:  1.202499031143757
# error: 0.2024990311437569
# Peso Wk:  [ 0.94498978 -0.60540283  0.13022732]
#
# Error de entrenamiento:  19.166666666666668
# Error de Prueba:  27.5
# iteraciones = 62
#
# g:  -0.42875661823321076
# error: 0.5712433817667892
# Peso Wk:  [ 0.9447347  -0.60532263  0.13009574]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 63
#
# g:  -1.2169627936518084
# error: -0.21696279365180837
# Peso Wk:  [ 0.944231   -0.60678879  0.12859176]
#
# Error de entrenamiento:  19.166666666666668
# Error de Prueba:  27.5
# iteraciones = 64
#
# g:  -0.9927917428945161
# error: 0.007208257105483895
# Peso Wk:  [ 0.94443187 -0.60597235  0.12906822]
#
# Error de entrenamiento:  19.166666666666668
# Error de Prueba:  27.5
# iteraciones = 65
#
# g:  -1.2934730008347821
# error: -0.2934730008347821
# Peso Wk:  [ 0.9444252  -0.60599866  0.12904486]
#
# Error de entrenamiento:  19.166666666666668
# Error de Prueba:  27.5
# iteraciones = 66
#
# g:  -0.39296568331526754
# error: 0.6070343166847325
# Peso Wk:  [ 0.9447105  -0.60479084  0.12976915]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 67
#
# g:  -0.332517975878858
# error: 0.667482024121142
# Peso Wk:  [ 0.94412037 -0.60646048  0.12807088]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 68
#
# g:  0.10390864010621592
# error: -0.8960913598937841
# Peso Wk:  [ 0.94366614 -0.60786623  0.12594197]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 69
#
# g:  0.39495532741177697
# error: -0.605044672588223
# Peso Wk:  [ 0.94430643 -0.60682596  0.12669361]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 70
#
# g:  -1.2243996430491895
# error: -0.22439964304918947
# Peso Wk:  [ 0.94473875 -0.60623239  0.12766209]
#
# Error de entrenamiento:  19.166666666666668
# Error de Prueba:  27.5
# iteraciones = 71
#
# g:  0.6150485903283233
# error: -0.38495140967167674
# Peso Wk:  [ 0.94489909 -0.60558246  0.12802404]
#
# Error de entrenamiento:  19.166666666666668
# Error de Prueba:  27.5
# iteraciones = 72
#
# g:  0.051131763311560885
# error: 1.0511317633115609
# Peso Wk:  [ 0.94509163 -0.60544489  0.12817868]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 73
#
# g:  1.2297397318089838
# error: 0.22973973180898377
# Peso Wk:  [ 0.94456589 -0.60652904  0.12672449]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 74
#
# g:  1.327021591681937
# error: 0.327021591681937
# Peso Wk:  [ 0.94444523 -0.60647025  0.12673434]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 75
#
# g:  0.10742031641035257
# error: -0.8925796835896475
# Peso Wk:  [ 0.94432501 -0.60645912  0.12642469]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 76
#
# g:  -1.2587228706816782
# error: -0.2587228706816782
# Peso Wk:  [ 0.94466955 -0.60589934  0.12682915]
#
# Error de entrenamiento:  19.166666666666668
# Error de Prueba:  27.5
# iteraciones = 77
#
# g:  -0.10815899260172623
# error: 0.8918410073982738
# Peso Wk:  [ 0.94476942 -0.60544974  0.12724201]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 78
#
# g:  1.2505335009386367
# error: 0.2505335009386367
# Peso Wk:  [ 0.94442517 -0.606298    0.12605452]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 79
#
# g:  0.39357623495378136
# error: -0.6064237650462186
# Peso Wk:  [ 0.94432362 -0.60630929  0.12575365]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 80
#
# g:  -0.43870446810699637
# error: -1.4387044681069963
# Peso Wk:  [ 0.9445817  -0.60595495  0.12633179]
#
# Error de entrenamiento:  19.166666666666668
# Error de Prueba:  27.5
# iteraciones = 81
#
# g:  0.9089797122650249
# error: -0.09102028773497506
# Peso Wk:  [ 0.94501029 -0.60487456  0.12682098]
#
# Error de entrenamiento:  19.166666666666668
# Error de Prueba:  27.5
# iteraciones = 82
#
# g:  1.0055829588053549
# error: 0.005582958805354865
# Peso Wk:  [ 0.94503741 -0.60486324  0.12686729]
#
# Error de entrenamiento:  19.166666666666668
# Error de Prueba:  27.5
# iteraciones = 83
#
# g:  -0.18439130499205297
# error: 0.8156086950079471
# Peso Wk:  [ 0.94503574 -0.60486372  0.12686421]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 84
#
# g:  -1.5090980218825356
# error: -0.5090980218825356
# Peso Wk:  [ 0.94486566 -0.60529433  0.12632527]
#
# Error de entrenamiento:  19.166666666666668
# Error de Prueba:  27.5
# iteraciones = 85
#
# g:  -0.7673486253483182
# error: 0.23265137465168184
# Peso Wk:  [ 0.94497713 -0.60475407  0.12674859]
#
# Error de entrenamiento:  19.166666666666668
# Error de Prueba:  27.5
# iteraciones = 86
#
# g:  -0.21196099992179723
# error: 0.7880390000782027
# Peso Wk:  [ 0.94492619 -0.60493694  0.12656424]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 87
#
# g:  0.27791529783451313
# error: -0.7220847021654868
# Peso Wk:  [ 0.94480541 -0.60525495  0.12614827]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 88
#
# g:  -0.5764039003615153
# error: 0.42359609963848466
# Peso Wk:  [ 0.94492162 -0.60512983  0.12613428]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 89
#
# g:  -1.261690337942889
# error: -0.261690337942889
# Peso Wk:  [ 0.94485345 -0.6053375   0.1259602 ]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 90
#
# g:  0.5811745342714887
# error: -0.4188254657285113
# Peso Wk:  [ 0.94489767 -0.60515707  0.12605263]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 91
#
# g:  0.22667398896878702
# error: -0.773326011031213
# Peso Wk:  [ 0.94494721 -0.60511883  0.1260933 ]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 92
#
# g:  0.037669622549578285
# error: 1.0376696225495783
# Peso Wk:  [ 0.94501124 -0.60502801  0.12616438]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 93
#
# g:  -0.37341695957819754
# error: 0.6265830404218025
# Peso Wk:  [ 0.94492532 -0.60519783  0.12596793]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 94
#
# g:  0.505792398882058
# error: -0.49420760111794204
# Peso Wk:  [ 0.94487085 -0.60537098  0.12570614]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 95
#
# g:  0.8395209018495848
# error: -0.16047909815041517
# Peso Wk:  [ 0.94491596 -0.60532979  0.12574695]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 96
#
# g:  0.7433831424929175
# error: -0.2566168575070825
# Peso Wk:  [ 0.94493061 -0.60531987  0.1257824 ]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 97
#
# g:  0.15265317717680874
# error: -0.8473468228231913
# Peso Wk:  [ 0.94494701 -0.60531249  0.12579164]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 98
#
# g:  -1.0845822082938632
# error: -0.0845822082938632
# Peso Wk:  [ 0.94498491 -0.60525204  0.12584379]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 99
#
# g:  0.0813986678746173
# error: -0.9186013321253828
# Peso Wk:  [ 0.9449887  -0.60523531  0.12586328]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 100
#
# g:  0.9733784246862278
# error: -0.026621575313772183
# Peso Wk:  [ 0.94501746 -0.60518178  0.1259233 ]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 101
#
# g:  0.7145060280535798
# error: -0.28549397194642023
# Peso Wk:  [ 0.94501829 -0.60518164  0.12592418]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 102
#
# g:  -0.7167389235544724
# error: -1.7167389235544723
# Peso Wk:  [ 0.94502455 -0.60517778  0.12593125]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 103
#
# g:  1.2510830529436612
# error: 0.2510830529436612
# Peso Wk:  [ 0.94505089 -0.60509455  0.12598367]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 104
#
# g:  -0.7863481401567627
# error: 0.2136518598432373
# Peso Wk:  [ 0.94504704 -0.60509498  0.12597225]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 105
#
# g:  -0.28121043018799574
# error: 0.7187895698120043
# Peso Wk:  [ 0.94504359 -0.60510647  0.12596435]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 106
#
# g:  0.37866514655634886
# error: -0.6213348534436511
# Peso Wk:  [ 0.94503549 -0.6051303   0.12592878]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 107
#
# g:  0.18228915038780255
# error: -0.8177108496121974
# Peso Wk:  [ 0.94504285 -0.60512112  0.12593983]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 108
#
# g:  1.5509236933803567
# error: 0.5509236933803567
# Peso Wk:  [ 0.94504962 -0.60510997  0.12595236]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 109
#
# g:  1.8629958010516445
# error: 0.8629958010516445
# Peso Wk:  [ 0.94504506 -0.6051068   0.12594559]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 110
#
# g:  0.5538320899634765
# error: -0.44616791003652345
# Peso Wk:  [ 0.94504005 -0.60509915  0.12594589]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 111
#
# g:  -1.1143559693481302
# error: -0.1143559693481302
# Peso Wk:  [ 0.94504277 -0.60509716  0.12594697]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 112
#
# g:  -1.0201214700676053
# error: -0.02012147006760534
# Peso Wk:  [ 0.94504346 -0.60509424  0.12594961]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 113
#
# g:  -1.168846515878075
# error: -0.16884651587807498
# Peso Wk:  [ 0.94504359 -0.60509377  0.12594997]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 114
#
# g:  0.7190860639740698
# error: -0.2809139360259302
# Peso Wk:  [ 0.94504431 -0.60509086  0.12595188]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 115
#
# g:  0.7236382110862862
# error: -0.27636178891371377
# Peso Wk:  [ 0.94504515 -0.60509022  0.12595343]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 116
#
# g:  0.7113073849739964
# error: -0.28869261502600363
# Peso Wk:  [ 0.94504597 -0.60509002  0.12595296]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 117
#
# g:  -0.05310775174417143
# error: -1.0531077517441714
# Peso Wk:  [ 0.94504657 -0.60508953  0.12595417]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 118
#
# g:  0.23117117962334882
# error: 1.2311711796233489
# Peso Wk:  [ 0.94504811 -0.60508637  0.12595715]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 119
#
# g:  0.14476657582591035
# error: 1.1447665758259102
# Peso Wk:  [ 0.94504631 -0.60508992  0.12595031]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 120
#
# g:  -0.2521854125829298
# error: 0.7478145874170702
# Peso Wk:  [ 0.94504456 -0.60509332  0.12594517]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 121
#
# g:  -1.2353111765605702
# error: -0.2353111765605702
# Peso Wk:  [ 0.94504335 -0.60509677  0.12594005]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 122
#
# g:  0.39638511599311965
# error: -0.6036148840068803
# Peso Wk:  [ 0.94504375 -0.60509497  0.12594181]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 123
#
# g:  0.14473665412897557
# error: 1.1447366541289756
# Peso Wk:  [ 0.94504446 -0.60509398  0.12594341]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 124
#
# g:  -0.8129029110872181
# error: 0.18709708891278187
# Peso Wk:  [ 0.94504311 -0.6050966   0.12593944]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 125
#
# g:  -0.0005007379526018041
# error: 0.9994992620473981
# Peso Wk:  [ 0.94504287 -0.60509742  0.12593877]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 126
#
# g:  0.11089377086908689
# error: -0.8891062291309131
# Peso Wk:  [ 0.945042   -0.60509899  0.12593775]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 127
#
# g:  -0.914421135057205
# error: -1.914421135057205
# Peso Wk:  [ 0.94504282 -0.60509779  0.12593814]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 128
#
# g:  -0.9825346535299864
# error: 0.017465346470013632
# Peso Wk:  [ 0.94504404 -0.60509421  0.12593727]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 129
#
# g:  -1.2872079124946938
# error: -0.2872079124946938
# Peso Wk:  [ 0.94504403 -0.60509425  0.12593723]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 130
#
# g:  1.0527415086744507
# error: 0.05274150867445071
# Peso Wk:  [ 0.94504422 -0.60509343  0.12593774]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 131
#
# g:  0.7112723513675628
# error: -0.28872764863243716
# Peso Wk:  [ 0.94504419 -0.60509343  0.12593771]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 132
#
# g:  0.2869458043915014
# error: -0.7130541956084986
# Peso Wk:  [ 0.94504439 -0.60509327  0.12593812]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 133
#
# g:  0.1764153675082665
# error: -0.8235846324917335
# Peso Wk:  [ 0.94504474 -0.60509279  0.12593857]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 134
#
# g:  -1.8904648450152297
# error: -0.8904648450152297
# Peso Wk:  [ 0.94504503 -0.60509237  0.12593883]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 135
#
# g:  -0.18191306878547153
# error: 0.8180869312145285
# Peso Wk:  [ 0.94504524 -0.60509122  0.12593952]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 136
#
# g:  0.2754910495616645
# error: -0.7245089504383355
# Peso Wk:  [ 0.94504505 -0.60509179  0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 137
#
# g:  0.8661919886985835
# error: -0.1338080113014165
# Peso Wk:  [ 0.94504523 -0.60509152  0.12593886]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 138
#
# g:  -0.8251188940457367
# error: 0.17488110595426332
# Peso Wk:  [ 0.94504527 -0.60509152  0.12593887]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 139
#
# g:  -0.9827297783047393
# error: 0.017270221695260712
# Peso Wk:  [ 0.94504522 -0.60509167  0.12593874]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 140
#
# g:  -0.32363413335625624
# error: 0.6763658666437438
# Peso Wk:  [ 0.94504522 -0.60509169  0.12593872]
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 141
#
# g:  -0.5882019064944888
# error: 0.4117980935055112
# Peso Wk:  [ 0.94504509 -0.60509201  0.12593844]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 142
#
# g:  0.553838992364614
# error: -0.446161007635386
# Peso Wk:  [ 0.94504501 -0.60509227  0.12593819]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 143
#
# g:  -0.47947185385090296
# error: -1.479471853850903
# Peso Wk:  [ 0.9450451  -0.6050922   0.12593823]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 144
#
# g:  -0.6544561138017699
# error: 0.34554388619823007
# Peso Wk:  [ 0.94504531 -0.60509164  0.12593854]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 145
#
# g:  0.3214777572146829
# error: -0.678522242785317
# Peso Wk:  [ 0.94504526 -0.60509179  0.12593845]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 146
#
# g:  0.10008101134671422
# error: -0.8999189886532858
# Peso Wk:  [ 0.94504537 -0.60509166  0.12593854]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 147
#
# g:  -1.712546465969746
# error: -0.712546465969746
# Peso Wk:  [ 0.94504546 -0.60509153  0.12593854]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 148
#
# g:  -1.0619258760301464
# error: -0.06192587603014643
# Peso Wk:  [ 0.94504554 -0.60509116  0.1259387 ]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 149
#
# g:  -0.6544540514315207
# error: 0.3455459485684793
# Peso Wk:  [ 0.94504554 -0.60509114  0.12593872]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 150
#
# g:  0.5123701215038183
# error: -0.48762987849618167
# Peso Wk:  [ 0.94504551 -0.60509125  0.12593865]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 151
#
# g:  -0.9891420189019229
# error: 0.010857981098077119
# Peso Wk:  [ 0.94504556 -0.60509122  0.12593861]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 152
#
# g:  -0.1718753095824906
# error: -1.1718753095824905
# Peso Wk:  [ 0.94504556 -0.60509122  0.12593861]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 153
#
# g:  -1.4741746858064175
# error: -0.47417468580641753
# Peso Wk:  [ 0.9450457  -0.60509095  0.12593872]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 154
#
# g:  0.7625634367131048
# error: -0.23743656328689522
# Peso Wk:  [ 0.94504575 -0.60509069  0.12593889]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 155
#
# g:  -0.6646739069369745
# error: 0.3353260930630255
# Peso Wk:  [ 0.94504578 -0.60509068  0.12593892]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 156
#
# g:  -0.6466016356707265
# error: 0.3533983643292735
# Peso Wk:  [ 0.94504574 -0.6050908   0.12593884]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 157
#
# g:  -0.49993184050792133
# error: -1.4999318405079214
# Peso Wk:  [ 0.94504571 -0.6050909   0.1259387 ]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 158
#
# g:  -0.3879018734443218
# error: -1.3879018734443218
# Peso Wk:  [ 0.94504584 -0.60509061  0.12593863]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 159
#
# g:  -0.44410694870574813
# error: 0.5558930512942519
# Peso Wk:  [ 0.94504596 -0.60509032  0.12593874]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 160
#
# g:  -1.215538438216892
# error: -0.2155384382168919
# Peso Wk:  [ 0.94504591 -0.60509047  0.12593858]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 161
#
# g:  -0.553305725165032
# error: -1.553305725165032
# Peso Wk:  [ 0.94504593 -0.60509039  0.12593862]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 162
#
# g:  -1.0833165319346156
# error: -0.08331653193461563
# Peso Wk:  [ 0.94504603 -0.60509015  0.12593858]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 163
#
# g:  -0.4045003879205823
# error: 0.5954996120794177
# Peso Wk:  [ 0.94504604 -0.60509013  0.1259386 ]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 164
#
# g:  1.2912544770865229
# error: 0.29125447708652286
# Peso Wk:  [ 0.945046   -0.60509024  0.12593849]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 165
#
# g:  0.17642023165173182
# error: -0.8235797683482682
# Peso Wk:  [ 0.94504598 -0.60509023  0.12593846]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 166
#
# g:  -0.8021412046327007
# error: 0.19785879536729933
# Peso Wk:  [ 0.94504604 -0.60509015  0.12593851]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 167
#
# g:  0.6570248776815625
# error: -0.3429751223184375
# Peso Wk:  [ 0.94504602 -0.6050902   0.12593847]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 168
#
# g:  -0.7616458729919404
# error: 0.23835412700805958
# Peso Wk:  [ 0.94504605 -0.60509018  0.1259385 ]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 169
#
# g:  0.044383258309469015
# error: -0.955616741690531
# Peso Wk:  [ 0.94504603 -0.60509025  0.12593842]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 170
#
# g:  1.0527441414574819
# error: 0.05274414145748185
# Peso Wk:  [ 0.9450461  -0.60509011  0.12593853]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 171
#
# g:  -1.8904526351603468
# error: -0.8904526351603468
# Peso Wk:  [ 0.9450461  -0.60509011  0.12593853]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 172
#
# g:  -0.6106097213598592
# error: 0.38939027864014075
# Peso Wk:  [ 0.94504617 -0.60508973  0.12593876]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 173
#
# g:  -0.14844692034625945
# error: 0.8515530796537405
# Peso Wk:  [ 0.94504614 -0.60508984  0.12593861]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 174
#
# g:  -0.031044972180444844
# error: -1.0310449721804449
# Peso Wk:  [ 0.94504609 -0.60508995  0.1259385 ]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 175
#
# g:  0.3963870749647479
# error: -0.6036129250352521
# Peso Wk:  [ 0.94504615 -0.60508986  0.12593848]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 176
#
# g:  0.6570254040108388
# error: -0.34297459598916125
# Peso Wk:  [ 0.94504619 -0.60508981  0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 177
#
# g:  -0.3373440129555665
# error: 0.6626559870444335
# Peso Wk:  [ 0.94504621 -0.60508979  0.12593858]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 178
#
# g:  0.33902102477154344
# error: -0.6609789752284565
# Peso Wk:  [ 0.94504617 -0.60508992  0.12593839]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 179
#
# g:  -0.7511751692324549
# error: 0.24882483076754514
# Peso Wk:  [ 0.94504621 -0.60508986  0.12593845]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 180
#
# g:  -0.025236499196137352
# error: -1.0252364991961374
# Peso Wk:  [ 0.9450462  -0.60508992  0.12593839]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 181
#
# g:  -0.6795115502722207
# error: -1.6795115502722207
# Peso Wk:  [ 0.94504626 -0.60508978  0.12593853]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 182
#
# g:  -0.7936669745746029
# error: 0.2063330254253971
# Peso Wk:  [ 0.94504634 -0.60508956  0.1259386 ]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 183
#
# g:  0.525105942358753
# error: -0.47489405764124704
# Peso Wk:  [ 0.94504633 -0.60508959  0.12593858]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 184
#
# g:  -0.4116761571229743
# error: -1.4116761571229743
# Peso Wk:  [ 0.94504635 -0.60508957  0.12593861]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 185
#
# g:  0.396388268834574
# error: -0.603611731165426
# Peso Wk:  [ 0.9450464  -0.60508946  0.12593865]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 186
#
# g:  0.5251063041826698
# error: -0.4748936958173302
# Peso Wk:  [ 0.94504642 -0.60508943  0.1259387 ]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 187
#
# g:  -0.19621843407870493
# error: 0.803781565921295
# Peso Wk:  [ 0.94504644 -0.60508941  0.12593871]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 188
#
# g:  0.14473328207925362
# error: 1.1447332820792537
# Peso Wk:  [ 0.94504641 -0.60508948  0.12593862]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 189
#
# g:  -0.04212139115347077
# error: -1.0421213911534708
# Peso Wk:  [ 0.94504638 -0.60508954  0.12593854]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 190
#
# g:  -0.9424123407115141
# error: 0.05758765928848586
# Peso Wk:  [ 0.94504641 -0.60508949  0.12593857]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 191
#
# g:  0.8535160716600335
# error: -0.14648392833996648
# Peso Wk:  [ 0.94504641 -0.60508949  0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 192
#
# g:  0.20484929332250973
# error: -0.7951507066774903
# Peso Wk:  [ 0.94504641 -0.60508949  0.12593857]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 193
#
# g:  0.8661934990604209
# error: -0.13380650093957913
# Peso Wk:  [ 0.94504642 -0.60508947  0.1259386 ]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 194
#
# g:  0.2735752361339809
# error: -0.7264247638660191
# Peso Wk:  [ 0.94504643 -0.60508947  0.1259386 ]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 195
#
# g:  1.2002447936454093
# error: 0.20024479364540926
# Peso Wk:  [ 0.94504644 -0.60508946  0.1259386 ]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 196
#
# g:  -0.8658558287054691
# error: 0.13414417129453093
# Peso Wk:  [ 0.94504643 -0.60508946  0.1259386 ]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 197
#
# g:  0.27835975625030057
# error: -0.7216402437496994
# Peso Wk:  [ 0.94504643 -0.60508946  0.12593859]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 198
#
# g:  -0.9145094080263387
# error: 0.08549059197366127
# Peso Wk:  [ 0.94504644 -0.60508945  0.12593859]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 199
#
# g:  -0.982509159294874
# error: 0.017490840705125965
# Peso Wk:  [ 0.94504644 -0.60508946  0.12593859]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 200
#
# g:  0.9564291018484754
# error: -0.043570898151524595
# Peso Wk:  [ 0.94504644 -0.60508946  0.12593859]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 201
#
# g:  0.153310477376267
# error: -0.846689522623733
# Peso Wk:  [ 0.94504644 -0.60508946  0.12593859]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 202
#
# g:  0.10064332956436688
# error: -0.8993566704356332
# Peso Wk:  [ 0.94504645 -0.60508944  0.1259386 ]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 203
#
# g:  -0.5034514072285858
# error: -1.5034514072285858
# Peso Wk:  [ 0.94504646 -0.60508943  0.1259386 ]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 204
#
# g:  0.14297834863454306
# error: 1.142978348634543
# Peso Wk:  [ 0.94504647 -0.60508941  0.12593861]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 205
#
# g:  1.5508858869036906
# error: 0.5508858869036906
# Peso Wk:  [ 0.94504646 -0.60508942  0.12593859]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 206
#
# g:  0.842612089180031
# error: -0.15738791081996895
# Peso Wk:  [ 0.94504646 -0.60508942  0.12593859]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 207
#
# g:  -0.36526187404009786
# error: 0.6347381259599021
# Peso Wk:  [ 0.94504646 -0.60508942  0.12593859]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 208
#
# g:  -0.36058509979177356
# error: 0.6394149002082264
# Peso Wk:  [ 0.94504645 -0.60508943  0.12593857]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 209
#
# g:  1.0211200693593003
# error: 0.02112006935930033
# Peso Wk:  [ 0.94504645 -0.60508944  0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 210
#
# g:  -0.7165634107101259
# error: 0.28343658928987414
# Peso Wk:  [ 0.94504645 -0.60508944  0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 211
#
# g:  -1.296888458782567
# error: -0.2968884587825671
# Peso Wk:  [ 0.94504645 -0.60508945  0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 212
#
# g:  0.14484003054108874
# error: -0.8551599694589113
# Peso Wk:  [ 0.94504645 -0.60508944  0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 213
#
# g:  0.6093769283174486
# error: -0.3906230716825514
# Peso Wk:  [ 0.94504645 -0.60508944  0.12593857]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 214
#
# g:  -1.3460159306929407
# error: -0.3460159306929407
# Peso Wk:  [ 0.94504645 -0.60508944  0.12593857]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 215
#
# g:  0.25710799364882964
# error: -0.7428920063511704
# Peso Wk:  [ 0.94504645 -0.60508943  0.12593857]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 216
#
# g:  0.6532290805559475
# error: 1.6532290805559475
# Peso Wk:  [ 0.94504646 -0.60508943  0.12593858]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 217
#
# g:  -0.4116757634225404
# error: -1.4116757634225405
# Peso Wk:  [ 0.94504645 -0.60508943  0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 218
#
# g:  -0.9827200757407317
# error: 0.017279924259268276
# Peso Wk:  [ 0.94504646 -0.60508943  0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 219
#
# g:  -1.260530388677381
# error: -0.2605303886773811
# Peso Wk:  [ 0.94504646 -0.60508943  0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 220
#
# g:  -1.2684510614949094
# error: -0.2684510614949094
# Peso Wk:  [ 0.94504646 -0.60508942  0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 221
#
# g:  -1.3677855468408864
# error: -0.3677855468408864
# Peso Wk:  [ 0.94504646 -0.60508942  0.12593857]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 222
#
# g:  0.32484352741969824
# error: -0.6751564725803018
# Peso Wk:  [ 0.94504646 -0.60508942  0.12593857]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 223
#
# g:  -0.05758365018150219
# error: 0.9424163498184979
# Peso Wk:  [ 0.94504646 -0.60508942  0.12593857]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 224
#
# g:  0.33902220542000483
# error: -0.6609777945799952
# Peso Wk:  [ 0.94504646 -0.60508942  0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 225
#
# g:  -0.10868705621250818
# error: 0.8913129437874918
# Peso Wk:  [ 0.94504646 -0.60508942  0.12593857]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 226
#
# g:  -0.39016469215447447
# error: 0.6098353078455255
# Peso Wk:  [ 0.94504646 -0.60508942  0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 227
#
# g:  0.5023679555472812
# error: -0.4976320444527188
# Peso Wk:  [ 0.94504646 -0.60508942  0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 228
#
# g:  -0.6392114844542901
# error: 0.3607885155457099
# Peso Wk:  [ 0.94504646 -0.60508942  0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 229
#
# g:  -0.746345064561289
# error: 0.253654935438711
# Peso Wk:  [ 0.94504646 -0.60508942  0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 230
#
# g:  -1.1836804211990466
# error: -2.1836804211990466
# Peso Wk:  [ 0.94504646 -0.60508943  0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 231
#
# g:  -0.742973604749118
# error: 0.257026395250882
# Peso Wk:  [ 0.94504646 -0.60508941  0.12593855]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 232
#
# g:  1.0928280678702447
# error: 0.09282806787024467
# Peso Wk:  [ 0.94504646 -0.60508942  0.12593855]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 233
#
# g:  1.0038055606616267
# error: 0.003805560661626739
# Peso Wk:  [ 0.94504646 -0.60508942  0.12593855]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 234
#
# g:  0.3024483332680364
# error: -0.6975516667319637
# Peso Wk:  [ 0.94504646 -0.60508942  0.12593855]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 235
#
# g:  -1.367785534153556
# error: -0.3677855341535561
# Peso Wk:  [ 0.94504646 -0.60508941  0.12593855]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 236
#
# g:  0.4042377610823298
# error: -0.5957622389176702
# Peso Wk:  [ 0.94504646 -0.60508941  0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 237
#
# g:  -1.270175095477746
# error: -0.270175095477746
# Peso Wk:  [ 0.94504646 -0.60508941  0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 238
#
# g:  0.32148193531702174
# error: -0.6785180646829783
# Peso Wk:  [ 0.94504646 -0.60508941  0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 239
#
# g:  0.199268916765615
# error: -0.800731083234385
# Peso Wk:  [ 0.94504646 -0.60508941  0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 240
#
# g:  -0.2389479080434848
# error: -1.2389479080434849
# Peso Wk:  [ 0.94504646 -0.60508941  0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 241
#
# g:  0.11116301370775186
# error: -0.8888369862922482
# Peso Wk:  [ 0.94504646 -0.60508941  0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 242
#
# g:  0.21849134559366445
# error: -0.7815086544063355
# Peso Wk:  [ 0.94504646 -0.60508941  0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 243
#
# g:  -1.2701750616990126
# error: -0.2701750616990126
# Peso Wk:  [ 0.94504646 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 244
#
# g:  1.5508858305690467
# error: 0.5508858305690467
# Peso Wk:  [ 0.94504646 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 245
#
# g:  -1.2871813601512232
# error: -0.2871813601512232
# Peso Wk:  [ 0.94504646 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 246
#
# g:  0.8025804826330262
# error: -0.19741951736697383
# Peso Wk:  [ 0.94504646 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 247
#
# g:  -0.19621890742275738
# error: 0.8037810925772426
# Peso Wk:  [ 0.94504646 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 248
#
# g:  0.7112795553370628
# error: -0.2887204446629372
# Peso Wk:  [ 0.94504646 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 249
#
# g:  -0.9996481457563429
# error: 0.0003518542436571348
# Peso Wk:  [ 0.94504646 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 250
#
# g:  -0.9996481457613048
# error: 0.00035185423869521504
# Peso Wk:  [ 0.94504646 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 251
#
# g:  0.2754958952264128
# error: -0.7245041047735872
# Peso Wk:  [ 0.94504646 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 252
#
# g:  0.10979648072405473
# error: -0.8902035192759452
# Peso Wk:  [ 0.94504646 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 253
#
# g:  -0.05313778145427375
# error: -1.0531377814542737
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 254
#
# g:  -0.4696812830141244
# error: -1.4696812830141244
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 255
#
# g:  -0.05383049657394767
# error: 0.9461695034260523
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 256
#
# g:  -0.1718707881844288
# error: -1.1718707881844288
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 257
#
# g:  -0.6544481745454538
# error: 0.3455518254545462
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# ...
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1915
#
# g:  -0.09027425988590304
# error: -1.090274259885903
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1916
#
# g:  -0.27177234101123915
# error: -1.2717723410112391
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1917
#
# g:  -0.23894788863835315
# error: -1.2389478886383531
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1918
#
# g:  1.1546238920106213
# error: 0.15462389201062132
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1919
#
# g:  1.550885826115283
# error: 0.5508858261152829
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1920
#
# g:  1.62460473267596
# error: 0.6246047326759601
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1921
#
# g:  -1.8904483508916996
# error: -0.8904483508916996
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1922
#
# g:  0.7436906703219853
# error: -0.2563093296780147
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1923
#
# g:  0.3214819516111693
# error: -0.6785180483888307
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1924
#
# g:  -0.7702801130061477
# error: 0.22971988699385226
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1925
#
# g:  -0.19016719066226268
# error: 0.8098328093377374
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1926
#
# g:  -1.3460158009580374
# error: -0.3460158009580374
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1927
#
# g:  -0.3652619230947405
# error: 0.6347380769052595
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1928
#
# g:  0.14473330988634875
# error: 1.1447333098863488
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1929
#
# g:  -0.1811684606335331
# error: 0.8188315393664669
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1930
#
# g:  1.2912548580205492
# error: 0.2912548580205492
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1931
#
# g:  -0.07093876904644655
# error: -1.0709387690464465
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1932
#
# g:  -0.5279522840665312
# error: 0.47204771593346884
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1933
#
# g:  0.6579165440168144
# error: -0.34208345598318557
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1934
#
# g:  0.32484354917706704
# error: -0.675156450822933
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1935
#
# g:  1.0937698344896938
# error: 0.09376983448969378
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1936
#
# g:  0.4675837151617451
# error: -0.532416284838255
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1937
#
# g:  1.0328711974079088
# error: 2.032871197407909
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1938
#
# g:  0.6083838373547222
# error: 1.6083838373547223
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1939
#
# g:  -0.7864074141770483
# error: 0.2135925858229517
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1940
#
# g:  0.3143528700616179
# error: -0.6856471299383822
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1941
#
# g:  -0.6513509308692971
# error: 0.3486490691307029
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1942
#
# g:  -0.28127055337770823
# error: 0.7187294466222918
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1943
#
# g:  -1.0476077320424055
# error: -0.04760773204240554
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1944
#
# g:  -1.1021370353636237
# error: -0.10213703536362373
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1945
#
# g:  1.309194035701383
# error: 0.30919403570138293
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1946
#
# g:  -1.1688561516504719
# error: -0.16885615165047185
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1947
#
# g:  -1.268450970180848
# error: -0.26845097018084796
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1948
#
# g:  0.14297821913899833
# error: 1.1429782191389983
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1949
#
# g:  -0.10446509914979629
# error: 0.8955349008502037
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1950
#
# g:  1.62460473267596
# error: 0.6246047326759601
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1951
#
# g:  -0.5034513614113951
# error: -1.5034513614113951
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1952
#
# g:  -0.6119613408906416
# error: 0.3880386591093584
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1953
#
# g:  -0.7909881342957938
# error: 0.20901186570420616
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1954
#
# g:  -1.1836803204577961
# error: -2.183680320457796
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1955
#
# g:  -1.0661226213399997
# error: -0.06612262133999969
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1956
#
# g:  -0.19621890073527942
# error: 0.8037810992647205
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1957
#
# g:  0.6138733186769411
# error: -0.38612668132305894
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1958
#
# g:  0.6866565397581031
# error: -0.31334346024189685
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1959
#
# g:  -0.5034513614113951
# error: -1.5034513614113951
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1960
#
# g:  -0.2522003338312867
# error: 0.7477996661687133
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1961
#
# g:  0.10979648840504003
# error: -0.89020351159496
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1962
#
# g:  0.553842693022401
# error: -0.44615730697759903
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1963
#
# g:  0.5734362988967336
# error: -0.42656370110326636
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1964
#
# g:  -0.4794625349624563
# error: -1.4794625349624564
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1965
#
# g:  0.3965045401871414
# error: -0.6034954598128586
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1966
#
# g:  1.1915791886654543
# error: 0.19157918866545431
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1967
#
# g:  -1.0946001792668834
# error: -0.09460017926688336
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1968
#
# g:  -0.6544481688713114
# error: 0.3455518311286886
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1969
#
# g:  1.164341557389145
# error: 0.1643415573891449
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1970
#
# g:  -0.4044980171415331
# error: 0.5955019828584669
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1971
#
# g:  0.16395740903557016
# error: 1.1639574090355702
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1972
#
# g:  1.62460473267596
# error: 0.6246047326759601
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1973
#
# g:  0.045205012694255024
# error: -0.954794987305745
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1974
#
# g:  -0.9996481261972698
# error: 0.00035187380273016267
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1975
#
# g:  -0.22835283292465286
# error: -1.228352832924653
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1976
#
# g:  -0.5015346123709138
# error: 0.4984653876290862
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1977
#
# g:  -0.9424119847960171
# error: 0.057588015203982934
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1978
#
# g:  -0.7936663980144578
# error: 0.20633360198554218
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1979
#
# g:  -0.1431213078838367
# error: 0.8568786921161633
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1980
#
# g:  -0.3652619230947405
# error: 0.6347380769052595
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1981
#
# g:  -0.031043770753550012
# error: -1.03104377075355
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1982
#
# g:  0.8904959799103487
# error: -0.10950402008965132
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1983
#
# g:  -0.7440293295770215
# error: 0.2559706704229785
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1984
#
# g:  -1.1688561516504719
# error: -0.16885615165047185
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1985
#
# g:  0.21849135598648353
# error: -0.7815086440135165
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1986
#
# g:  -0.32362737558085497
# error: 0.676372624419145
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1987
#
# g:  1.8629710087584133
# error: 0.8629710087584133
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1988
#
# g:  1.1546238920106213
# error: 0.15462389201062132
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1989
#
# g:  1.2159475656409724
# error: 0.2159475656409724
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1990
#
# g:  0.11868283071424021
# error: -0.8813171692857598
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1991
#
# g:  -0.03425134885753106
# error: -1.0342513488575311
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1992
#
# g:  -1.3460158009580374
# error: -0.3460158009580374
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1993
#
# g:  -1.509392517836175
# error: -0.5093925178361749
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1994
#
# g:  -1.2352813375061418
# error: -0.23528133750614177
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1995
#
# g:  -0.0004829001634190644
# error: 0.999517099836581
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1996
#
# g:  -0.19351697022835157
# error: 0.8064830297716484
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1997
#
# g:  0.11116302602041543
# error: -0.8888369739795846
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1998
#
# g:  -0.7909881342957938
# error: 0.20901186570420616
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5
# iteraciones = 1999
#
# g:  1.0590388324632758
# error: 2.059038832463276
# Peso Wk:  [ 0.94504647 -0.6050894   0.12593856]
#
# Error de entrenamiento:  18.88888888888889
# Error de Prueba:  27.5

# %%
plt.figure(figsize=(14,8))
plt.plot(error, 'b+')

# %%
plt.figure(figsize=(14,8))
plt.plot(V_errorEnt , 'g')

# %%
plt.figure(figsize=(14,8))
plt.plot(V_errorPru, 'g')
