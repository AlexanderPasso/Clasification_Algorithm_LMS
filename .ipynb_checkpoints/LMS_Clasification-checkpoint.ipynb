# %%
import numpy as np
import matplotlib.pyplot as plt 
import random                          # crear numeros aleatoriamente
import scipy.io as sio
from sklearn.model_selection import train_test_split

# %%
# cargar el archivo .mat
data = sio.loadmat('Tiosulfatosodio.mat')

#Extrayendo matriz de caracteristicas 
Xi = data['x']

#Extrayendo dato esperado (Clases)
Yi = data['y']

#Agregando el bias a las filas de la matriz de caracteristicas (Entradas)
bias = np.full((Xi.shape[0], 1), 1)
Xi = np.hstack((bias, Xi))

#numero de datos
num_datos = Xi.shape[0]

#numero de caracteristicas
caract = Xi.shape[1]-1                  # Se resta el bias 




#Definicion de errores
Err_entr = 10;
Err_pru = 10;

#Datos de entrenamiento y prueba: entrenamiento 90% , prueba 10%
X_ent, X_pru, Y_ent, Y_pru = train_test_split(Xi, Yi, test_size=0.1)

#Obteniendo datos de validacion: Validacion 10% y Entrenamiento 80%
#Se extraen los datos de validación a partir de los de entrenamiento
X_ent, X_val, Y_ent, Y_val = train_test_split(X_ent, Y_ent, test_size=0.1, random_state=42)

#Obteniendo datos de entrenamiento y prueba
D_entre  =  len(X_ent)       # datos de entrenamiento   (verificar la cantidad de dtos para hacer la particion)
D_prueba =  len(X_pru)       #Datos de validacion 
D_val    =  len(X_val)

print(D_entre)
# Out:
# 324

# %%
import matplotlib.pyplot as plt

# Crear la figura y los subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

# Graficar la segunda gráfica en el segundo subplot
ax1.scatter(Xi[:, 1], Xi[:, 2], c=Yi, cmap=plt.cm.coolwarm)
ax1.set_title('Datos Originales')
ax1.set_xlabel("X1")
ax1.set_ylabel("X2")

# Graficar la primera gráfica en el primer subplot
ax2.scatter(X_ent[:, 1], X_ent[:, 2], c=Y_ent, cmap=plt.cm.coolwarm)
ax2.set_title('Datos de Entrenamiento')
ax2.set_xlabel("X1")
ax2.set_ylabel("X2")


# Mostrar la figura
plt.show()

# %%
#Definicion de los pesos e inicialización 
Wk = []  
for i in range(Xi.shape[1]):                      # ciclo para agregar los numeros aleatorios con los que se inicializaran los pesos
    Wk.append(random.uniform(0,1))                # vector de pesos extendido
print(Wk)
# Out:
# [0.2025226736118777, 0.8503609239168951, 0.12888918512394176]

# %%
def error_entrenamiento(x,y,w,n) -> float:
    suma = 0
    vec_Ent  = []
    for i in range (n):
        g = np.dot(np.transpose(w), x[i])

        if g < 0:                # se establece un umbral para poder hacer clasificacion con el algoritmo LMS
            g = -1
        else:
            g = 1

        if g != y[i]:                   # Condicion de Error
            suma = suma + 1          # contador de errores

    error_pct = 100.0 * suma / n
    
    return error_pct

# %%
def error_prueba(x,y,w,n) -> float:
    suma = 0
    vec_Pru  = []
   
    for i in range (n):
        g = np.dot(np.transpose(w), x[i])

        if g < 0:                # se establece un umbral para poder hacer clasificacion con el algoritmo LMS
            g = -1
        else:
            g = 1

        if g != y[i]:                   # Condicion de Error
            suma = suma + 1          # contador de errores

    error_pct = 100.0 * suma / n
    
    return error_pct

# %%
e = 0
error_ent = []
u=0.1
suma=0
iteraciones = 0
Emin = 20
Eent =  0
print("Wo: ", Wk )

u = 0.1
gamma = 1.05
beta =  1.04
alpha = 0.7

V_errorEnt = []
V_errorPru = []


while( (iteraciones<1500)):

    ################## Error de entrenamiento  ###########################
    
    i = np.random.randint(0,D_entre)
    print("iteraciones =",iteraciones,"\n")
    Y = Y_ent[i][0]
    g = np.dot(np.transpose(Wk),X_ent[i]) #Funcion interna de la neurona. matmul permite multiplicar dos matrices
    print("g: ", g)
    e = (g - Y)  #Error entre la salida dada y la salida esperada 
    print("error:",e)
    
    error_ent.append(e)
    
    ########################################################################
   
    if( (error_ent[iteraciones]/error_ent[iteraciones-1])>beta):
        u = u*alpha
    elif(error_ent[iteraciones]<error_ent[iteraciones-1]):
        u = u*gamma

    print("Peso Wk: ", Wk , "\n")
    Eent  = error_entrenamiento(X_ent,Y_ent,Wk,D_entre)
    V_errorEnt.append(Eent) 
    print("Error de entrenamiento: ", Eent )
    Epru  = error_prueba(X_pru,Y_pru,Wk,D_prueba)
    V_errorPru.append(Epru)
    print("Error de Prueba: ",  Epru )
    
    
    Wk = Wk - e*u*X_ent[i]    #np.dot(value,Xi[i]) #Encuentro los nuevos valores de los pesos utilziando np.dot para multiplicar const * matriz
    
    iteraciones = iteraciones + 1;
# Out:
# Wo:  [0.2025226736118777, 0.8503609239168951, 0.12888918512394176]
# iteraciones = 0
#
# g:  1.3475639673755635
# error: 0.3475639673755635
# Peso Wk:  [0.2025226736118777, 0.8503609239168951, 0.12888918512394176]
#
# Error de entrenamiento:  54.01234567901235
# Error de Prueba:  52.5
# iteraciones = 1
#
# g:  2.317296024483681
# error: 1.317296024483681
# Peso Wk:  [0.16776628 0.80818822 0.09835526]
#
# Error de entrenamiento:  54.32098765432099
# Error de Prueba:  52.5
# iteraciones = 2
#
# g:  1.3916707812363802
# error: 2.39167078123638
# Peso Wk:  [ 0.07555556  0.57574499 -0.00689387]
#
# Error de entrenamiento:  55.55555555555556
# Error de Prueba:  60.0
# iteraciones = 3
#
# g:  -0.39176147604410505
# error: -1.391761476044105
# Peso Wk:  [-0.04163631  0.30235958 -0.46560248]
#
# Error de entrenamiento:  37.65432098765432
# Error de Prueba:  45.0
# iteraciones = 4
#
# g:  0.026130943035612586
# error: -0.9738690569643874
# Peso Wk:  [ 0.02996981  0.39697528 -0.35031299]
#
# Error de entrenamiento:  49.69135802469136
# Error de Prueba:  55.0
# iteraciones = 5
#
# g:  -0.010413645397134963
# error: -1.010413645397135
# Peso Wk:  [ 0.08007538  0.44263187 -0.29802579]
#
# Error de entrenamiento:  58.02469135802469
# Error de Prueba:  60.0
# iteraciones = 6
#
# g:  0.5961064808941784
# error: -0.4038935191058216
# Peso Wk:  [ 0.13466045  0.46537269 -0.24767724]
#
# Error de entrenamiento:  59.5679012345679
# Error de Prueba:  62.5
# iteraciones = 7
#
# g:  0.543115085693425
# error: -0.45688491430657496
# Peso Wk:  [ 0.15647979  0.50481345 -0.21422159]
#
# Error de entrenamiento:  58.95061728395062
# Error de Prueba:  62.5
# iteraciones = 8
#
# g:  1.3916010758067703
# error: 2.3916010758067703
# Peso Wk:  [ 0.17375723  0.51254832 -0.22717736]
#
# Error de entrenamiento:  58.95061728395062
# Error de Prueba:  65.0
# iteraciones = 9
#
# g:  -0.6790432789191112
# error: -1.6790432789191112
# Peso Wk:  [ 0.08331704  0.15962976 -0.53858949]
#
# Error de entrenamiento:  32.71604938271605
# Error de Prueba:  47.5
# iteraciones = 10
#
# g:  -0.46257871064365674
# error: 0.5374212893563433
# Peso Wk:  [ 0.14998604  0.21755672 -0.42705247]
#
# Error de entrenamiento:  32.098765432098766
# Error de Prueba:  35.0
# iteraciones = 11
#
# g:  0.05024862605388808
# error: -0.9497513739461119
# Peso Wk:  [ 0.1286469   0.13508215 -0.49967704]
#
# Error de entrenamiento:  31.48148148148148
# Error de Prueba:  40.0
# iteraciones = 12
#
# g:  -0.004340647376096685
# error: -1.0043406473760967
# Peso Wk:  [ 0.16824381  0.20911037 -0.47345166]
#
# Error de entrenamiento:  29.320987654320987
# Error de Prueba:  40.0
# iteraciones = 13
#
# g:  -0.6438921183003343
# error: -1.6438921183003343
# Peso Wk:  [ 0.19755479  0.22230051 -0.45694139]
#
# Error de entrenamiento:  31.48148148148148
# Error de Prueba:  32.5
# iteraciones = 14
#
# g:  -0.13610778273698976
# error: -1.1361077827369899
# Peso Wk:  [ 0.23113788  0.22367982 -0.39442788]
#
# Error de entrenamiento:  32.71604938271605
# Error de Prueba:  35.0
# iteraciones = 15
#
# g:  -0.09780980330142819
# error: 0.9021901966985718
# Peso Wk:  [ 0.25434745  0.24337792 -0.36164703]
#
# Error de entrenamiento:  34.5679012345679
# Error de Prueba:  37.5
# iteraciones = 16
#
# g:  -0.6929960304944204
# error: -1.6929960304944203
# Peso Wk:  [ 0.23591659  0.19123184 -0.41468705]
#
# Error de entrenamiento:  30.555555555555557
# Error de Prueba:  30.0
# iteraciones = 17
#
# g:  0.30596307097553643
# error: -0.6940369290244636
# Peso Wk:  [ 0.27223214  0.2547749  -0.30403631]
#
# Error de entrenamiento:  41.358024691358025
# Error de Prueba:  47.5
# iteraciones = 18
#
# g:  -0.024988554185436884
# error: 0.9750114458145631
# Peso Wk:  [ 0.28711955  0.24961942 -0.31000814]
#
# Error de entrenamiento:  39.81481481481482
# Error de Prueba:  42.5
# iteraciones = 19
#
# g:  -0.09666479318454035
# error: -1.0966647931845404
# Peso Wk:  [ 0.26620511  0.17392251 -0.39201562]
#
# Error de entrenamiento:  29.012345679012345
# Error de Prueba:  30.0
# iteraciones = 20
#
# g:  0.2185068944081202
# error: -0.7814931055918798
# Peso Wk:  [ 0.29090527  0.18737218 -0.36318476]
#
# Error de entrenamiento:  30.246913580246915
# Error de Prueba:  32.5
# iteraciones = 21
#
# g:  0.25982270642154304
# error: 1.259822706421543
# Peso Wk:  [ 0.30850683  0.21585921 -0.34497915]
#
# Error de entrenamiento:  31.790123456790123
# Error de Prueba:  37.5
# iteraciones = 22
#
# g:  -1.2899348315577464
# error: -0.28993483155774635
# Peso Wk:  [ 0.28013186  0.08446826 -0.43119699]
#
# Error de entrenamiento:  27.469135802469136
# Error de Prueba:  37.5
# iteraciones = 23
#
# g:  -0.9081977712650946
# error: 0.0918022287349054
# Peso Wk:  [ 0.28698857  0.1126589  -0.40070813]
#
# Error de entrenamiento:  25.925925925925927
# Error de Prueba:  30.0
# iteraciones = 24
#
# g:  -0.09408876302933722
# error: -1.0940887630293372
# Peso Wk:  [ 0.28481753  0.10771    -0.40857505]
#
# Error de entrenamiento:  25.308641975308642
# Error de Prueba:  32.5
# iteraciones = 25
#
# g:  -0.19155712554730597
# error: 0.808442874452694
# Peso Wk:  [ 0.31198549  0.14452149 -0.37367551]
#
# Error de entrenamiento:  25.925925925925927
# Error de Prueba:  27.5
# iteraciones = 26
#
# g:  0.5053426350827167
# error: -0.4946573649172833
# Peso Wk:  [ 0.29191057  0.0584704  -0.43400811]
#
# Error de entrenamiento:  27.160493827160494
# Error de Prueba:  37.5
# iteraciones = 27
#
# g:  -1.3428479603329113
# error: -0.3428479603329113
# Peso Wk:  [ 0.30480786  0.07393889 -0.43826666]
#
# Error de entrenamiento:  26.54320987654321
# Error de Prueba:  37.5
# iteraciones = 28
#
# g:  -0.9579082345350918
# error: 0.042091765464908226
# Peso Wk:  [ 0.31374699  0.09951891 -0.4003446 ]
#
# Error de entrenamiento:  25.308641975308642
# Error de Prueba:  30.0
# iteraciones = 29
#
# g:  0.07365172092921815
# error: -0.9263482790707819
# Peso Wk:  [ 0.31264953  0.09624757 -0.40464379]
#
# Error de entrenamiento:  25.308641975308642
# Error de Prueba:  32.5
# iteraciones = 30
#
# g:  -0.6787059391389103
# error: -1.6787059391389103
# Peso Wk:  [ 0.33801001  0.08827458 -0.39156137]
#
# Error de entrenamiento:  24.074074074074073
# Error de Prueba:  30.0
# iteraciones = 31
#
# g:  -0.23681476903793386
# error: 0.7631852309620661
# Peso Wk:  [ 0.37018036  0.08529625 -0.30870028]
#
# Error de entrenamiento:  21.604938271604937
# Error de Prueba:  22.5
# iteraciones = 32
#
# g:  -0.07309896995377885
# error: -1.073098969953779
# Peso Wk:  [ 0.35555485  0.03479237 -0.35141294]
#
# Error de entrenamiento:  22.839506172839506
# Error de Prueba:  30.0
# iteraciones = 33
#
# g:  0.18745775959945932
# error: -0.8125422404005407
# Peso Wk:  [ 0.37714771  0.08990594 -0.31961731]
#
# Error de entrenamiento:  21.604938271604937
# Error de Prueba:  22.5
# iteraciones = 34
#
# g:  0.21640404620326648
# error: -0.7835959537967335
# Peso Wk:  [ 0.39349766  0.13362456 -0.29761604]
#
# Error de entrenamiento:  24.074074074074073
# Error de Prueba:  32.5
# iteraciones = 35
#
# g:  -0.3553203372408097
# error: 0.6446796627591903
# Peso Wk:  [ 0.40926516  0.15548556 -0.27841852]
#
# Error de entrenamiento:  33.95061728395062
# Error de Prueba:  37.5
# iteraciones = 36
#
# g:  -0.17964309734496609
# error: 0.8203569026550339
# Peso Wk:  [ 0.39629293  0.13066776 -0.32790224]
#
# Error de entrenamiento:  25.308641975308642
# Error de Prueba:  30.0
# iteraciones = 37
#
# g:  -0.5205115762926671
# error: 0.4794884237073329
# Peso Wk:  [ 0.3847379   0.09215109 -0.36354656]
#
# Error de entrenamiento:  22.839506172839506
# Error de Prueba:  22.5
# iteraciones = 38
#
# g:  -1.0782408330635076
# error: -0.0782408330635076
# Peso Wk:  [ 0.37764643  0.07708191 -0.38502438]
#
# Error de entrenamiento:  21.91358024691358
# Error de Prueba:  27.5
# iteraciones = 39
#
# g:  -0.6125032749740877
# error: -1.6125032749740877
# Peso Wk:  [ 0.37886144  0.07929937 -0.37998613]
#
# Error de entrenamiento:  21.91358024691358
# Error de Prueba:  27.5
# iteraciones = 40
#
# g:  0.4804204511598167
# error: -0.5195795488401833
# Peso Wk:  [ 0.39638999  0.13671847 -0.32227224]
#
# Error de entrenamiento:  25.617283950617285
# Error de Prueba:  30.0
# iteraciones = 41
#
# g:  -0.00907315702667677
# error: 0.9909268429733232
# Peso Wk:  [ 0.40203802  0.14697377 -0.3193943 ]
#
# Error de entrenamiento:  24.074074074074073
# Error de Prueba:  30.0
# iteraciones = 42
#
# g:  0.3335089637424745
# error: 1.3335089637424744
# Peso Wk:  [ 0.39126626  0.10893238 -0.35076455]
#
# Error de entrenamiento:  23.14814814814815
# Error de Prueba:  25.0
# iteraciones = 43
#
# g:  0.40465306131777823
# error: -0.5953469386822218
# Peso Wk:  [ 0.38111922  0.06649025 -0.36561607]
#
# Error de entrenamiento:  20.987654320987655
# Error de Prueba:  27.5
# iteraciones = 44
#
# g:  0.046684195206339985
# error: -0.9533158047936601
# Peso Wk:  [ 0.38587589  0.07433591 -0.36449545]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 45
#
# g:  -0.4254718189233896
# error: 0.5745281810766104
# Peso Wk:  [ 0.39120761  0.08387708 -0.35758802]
#
# Error de entrenamiento:  21.604938271604937
# Error de Prueba:  22.5
# iteraciones = 46
#
# g:  -0.6890777340296902
# error: 0.3109222659703098
# Peso Wk:  [ 0.38799438  0.07498209 -0.36701301]
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 47
#
# g:  -0.49735326668877944
# error: 0.5026467333112206
# Peso Wk:  [ 0.3861685   0.06679754 -0.37404354]
#
# Error de entrenamiento:  20.987654320987655
# Error de Prueba:  27.5
# iteraciones = 48
#
# g:  0.2978890886748098
# error: -0.7021109113251902
# Peso Wk:  [ 0.38410226  0.05714687 -0.38064761]
#
# Error de entrenamiento:  22.22222222222222
# Error de Prueba:  27.5
# iteraciones = 49
#
# g:  -1.2392190253613826
# error: -0.23921902536138262
# Peso Wk:  [ 0.38713275  0.06291424 -0.37909538]
#
# Error de entrenamiento:  21.604938271604937
# Error de Prueba:  27.5
# iteraciones = 50
#
# g:  -0.6812666924917319
# error: 0.3187333075082681
# Peso Wk:  [ 0.38816528  0.0636677  -0.37454069]
#
# Error de entrenamiento:  21.296296296296298
# Error de Prueba:  27.5
# iteraciones = 51
#
# g:  -0.11941860286727679
# error: 0.8805813971327232
# Peso Wk:  [ 0.38678954  0.06069744 -0.37897376]
#
# Error de entrenamiento:  21.604938271604937
# Error de Prueba:  27.5
# iteraciones = 52
#
# g:  -0.24748740480304598
# error: -1.247487404803046
# Peso Wk:  [ 0.38412897  0.04784395 -0.38458622]
#
# Error de entrenamiento:  22.839506172839506
# Error de Prueba:  30.0
# iteraciones = 53
#
# g:  -0.8623908887726546
# error: 0.13760911122734543
# Peso Wk:  [ 0.38808656  0.0516838  -0.37760887]
#
# Error de entrenamiento:  22.22222222222222
# Error de Prueba:  30.0
# iteraciones = 54
#
# g:  0.05159888699013143
# error: -0.9484011130098686
# Peso Wk:  [ 0.38765001  0.05068867 -0.37919077]
#
# Error de entrenamiento:  22.22222222222222
# Error de Prueba:  30.0
# iteraciones = 55
#
# g:  -0.23491661241464445
# error: -1.2349166124146445
# Peso Wk:  [ 0.3908092   0.06000998 -0.37514495]
#
# Error de entrenamiento:  21.296296296296298
# Error de Prueba:  27.5
# iteraciones = 56
#
# g:  0.023238938762850048
# error: -0.97676106123715
# Peso Wk:  [ 0.39368871  0.06098796 -0.3701856 ]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  27.5
# iteraciones = 57
#
# g:  0.08434000075852088
# error: -0.9156599992414791
# Peso Wk:  [ 0.39596628  0.06506368 -0.36723494]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 58
#
# g:  -0.21498283182860656
# error: -1.2149828318286064
# Peso Wk:  [ 0.39810136  0.06595319 -0.36526556]
#
# Error de entrenamiento:  19.753086419753085
# Error de Prueba:  25.0
# iteraciones = 59
#
# g:  0.14134755950628708
# error: -0.8586524404937129
# Peso Wk:  [ 0.40008449  0.06916369 -0.36135727]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 60
#
# g:  -0.3634604648546319
# error: 0.6365395351453681
# Peso Wk:  [ 0.401486    0.07294303 -0.3596304 ]
#
# Error de entrenamiento:  20.987654320987655
# Error de Prueba:  25.0
# iteraciones = 61
#
# g:  0.025330940635252708
# error: -0.9746690593647473
# Peso Wk:  [ 0.40044703  0.06737949 -0.36296878]
#
# Error de entrenamiento:  20.061728395061728
# Error de Prueba:  25.0
# iteraciones = 62
#
# g:  -0.08238253371804816
# error: -1.0823825337180482
# Peso Wk:  [ 0.40211745  0.0661247  -0.36147538]
#
# Error de entrenamiento:  20.061728395061728
# Error de Prueba:  25.0
# iteraciones = 63
#
# g:  0.07030624760739124
# error: -0.9296937523926088
# Peso Wk:  [ 0.40341597  0.067995   -0.35939279]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 64
#
# g:  0.9032417218407254
# error: -0.09675827815927462
# Peso Wk:  [ 0.40453131  0.06880335 -0.35820609]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 65
#
# g:  -0.7678317490588149
# error: 0.2321682509411851
# Peso Wk:  [ 0.40464739  0.06901725 -0.35832661]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 66
#
# g:  0.43871649693313536
# error: -0.5612835030668646
# Peso Wk:  [ 0.40436886  0.06845553 -0.35934618]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 67
#
# g:  0.17365572642674204
# error: -0.826344273573258
# Peso Wk:  [ 0.40507589  0.06937296 -0.35923899]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 68
#
# g:  -0.6913736401827704
# error: 0.30862635981722963
# Peso Wk:  [ 0.40580454  0.07025708 -0.35859886]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 69
#
# g:  0.5831989044803539
# error: -0.41680109551964606
# Peso Wk:  [ 0.4055324   0.06938578 -0.35960221]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 70
#
# g:  0.33987480479207477
# error: -0.6601251952079252
# Peso Wk:  [ 0.4059183   0.06970828 -0.35973064]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 71
#
# g:  0.09947861250276635
# error: -0.9005213874972336
# Peso Wk:  [ 0.40634612  0.07018218 -0.35956026]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 72
#
# g:  -0.6570413053937671
# error: 0.34295869460623285
# Peso Wk:  [ 0.40675466  0.07013211 -0.35922136]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 73
#
# g:  0.34981514329349905
# error: -0.650184856706501
# Peso Wk:  [ 0.40659907  0.06968863 -0.35976871]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 74
#
# g:  -0.1749141819368914
# error: -1.1749141819368913
# Peso Wk:  [ 0.40690879  0.070251   -0.35961089]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 75
#
# g:  0.3149733370694876
# error: -0.6850266629305124
# Peso Wk:  [ 0.40730056  0.06997963 -0.35903005]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 76
#
# g:  -0.5445192489375569
# error: -1.544519248937557
# Peso Wk:  [ 0.40752898  0.0701463  -0.35893882]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 77
#
# g:  0.7080875893649625
# error: -0.2919124106350375
# Peso Wk:  [ 0.40788949  0.07132724 -0.35775182]
#
# Error de entrenamiento:  20.987654320987655
# Error de Prueba:  25.0
# iteraciones = 78
#
# g:  0.6503481766827253
# error: -0.34965182331727473
# Peso Wk:  [ 0.40795763  0.07135774 -0.35780291]
#
# Error de entrenamiento:  20.987654320987655
# Error de Prueba:  25.0
# iteraciones = 79
#
# g:  0.276231626884478
# error: -0.723768373115522
# Peso Wk:  [ 0.40801476  0.07144549 -0.35782411]
#
# Error de entrenamiento:  20.987654320987655
# Error de Prueba:  25.0
# iteraciones = 80
#
# g:  -0.48746608804626856
# error: 0.5125339119537314
# Peso Wk:  [ 0.40809754  0.07143101 -0.35779652]
#
# Error de entrenamiento:  20.987654320987655
# Error de Prueba:  25.0
# iteraciones = 81
#
# g:  -0.6510216016314394
# error: 0.3489783983685606
# Peso Wk:  [ 0.40803892  0.07124177 -0.35798102]
#
# Error de entrenamiento:  20.987654320987655
# Error de Prueba:  25.0
# iteraciones = 82
#
# g:  -0.8375220109560897
# error: 0.1624779890439103
# Peso Wk:  [ 0.40799701  0.07105391 -0.35814239]
#
# Error de entrenamiento:  20.987654320987655
# Error de Prueba:  25.0
# iteraciones = 83
#
# g:  0.44001591650623484
# error: -0.5599840834937652
# Peso Wk:  [ 0.40797652  0.07101489 -0.35822139]
#
# Error de entrenamiento:  20.987654320987655
# Error de Prueba:  25.0
# iteraciones = 84
#
# g:  -0.7558503143467925
# error: 0.2441496856532075
# Peso Wk:  [ 0.40805066  0.07102042 -0.35822692]
#
# Error de entrenamiento:  20.987654320987655
# Error de Prueba:  25.0
# iteraciones = 85
#
# g:  -0.9775963532891666
# error: 0.02240364671083339
# Peso Wk:  [ 0.40801834  0.0709389  -0.35834811]
#
# Error de entrenamiento:  20.987654320987655
# Error de Prueba:  25.0
# iteraciones = 86
#
# g:  0.14690340086680453
# error: 1.1469034008668046
# Peso Wk:  [ 0.40801522  0.07092712 -0.35836248]
#
# Error de entrenamiento:  20.987654320987655
# Error de Prueba:  25.0
# iteraciones = 87
#
# g:  0.20337138195218168
# error: 1.2033713819521816
# Peso Wk:  [ 0.40790361  0.07064938 -0.35849878]
#
# Error de entrenamiento:  20.987654320987655
# Error de Prueba:  25.0
# iteraciones = 88
#
# g:  0.3868981688368758
# error: -0.6131018311631242
# Peso Wk:  [ 0.40782164  0.07035773 -0.35860302]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 89
#
# g:  0.17756805254885943
# error: 1.1775680525488594
# Peso Wk:  [ 0.40786549  0.07041935 -0.35858837]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 90
#
# g:  -0.8106342269002288
# error: -1.8106342269002287
# Peso Wk:  [ 0.40778127  0.07006705 -0.35871165]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 91
#
# g:  0.06934618734050813
# error: -0.9306538126594919
# Peso Wk:  [ 0.40791725  0.07014944 -0.35823367]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 92
#
# g:  -0.41835423382665105
# error: 0.581645766173349
# Peso Wk:  [ 0.40798714  0.07027452 -0.35814312]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 93
#
# g:  0.07363330870277601
# error: -0.9263666912972239
# Peso Wk:  [ 0.40794346  0.07010159 -0.35827784]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 94
#
# g:  -0.4927715816825968
# error: 0.5072284183174032
# Peso Wk:  [ 0.40801651  0.07019725 -0.35819096]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 95
#
# g:  -0.4421547602477808
# error: 0.5578452397522192
# Peso Wk:  [ 0.40797651  0.07006812 -0.35831686]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 96
#
# g:  0.24980156809231516
# error: -0.7501984319076849
# Peso Wk:  [ 0.40794572  0.0700012  -0.358403  ]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 97
#
# g:  -0.037195790534522155
# error: 0.9628042094654778
# Peso Wk:  [ 0.4079892   0.070043   -0.35837565]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 98
#
# g:  -0.8258153563190658
# error: 0.17418464368093423
# Peso Wk:  [ 0.4079334   0.06988095 -0.35847664]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 99
#
# g:  -0.8266234858491366
# error: 0.17337651415086341
# Peso Wk:  [ 0.4079228   0.06986067 -0.35851708]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 100
#
# g:  -0.9133269474478465
# error: 0.08667305255215352
# Peso Wk:  [ 0.40791172  0.06984205 -0.35855886]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 101
#
# g:  0.3910874194399902
# error: -0.6089125805600097
# Peso Wk:  [ 0.4079059   0.06982541 -0.35858353]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 102
#
# g:  -0.8336867354185166
# error: 0.16631326458148343
# Peso Wk:  [ 0.4079488   0.06978645 -0.3585891 ]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 103
#
# g:  0.10619472740243713
# error: -0.8938052725975629
# Peso Wk:  [ 0.40793708  0.06975118 -0.35863654]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 104
#
# g:  0.6097569981974192
# error: -0.39024300180258076
# Peso Wk:  [ 0.4080032   0.06977872 -0.35857555]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 105
#
# g:  0.2222135199971128
# error: -0.7777864800028872
# Peso Wk:  [ 0.40803207  0.06981688 -0.35858437]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 106
#
# g:  -0.6911107541958235
# error: 0.30888924580417654
# Peso Wk:  [ 0.40807234  0.06988989 -0.35854928]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 107
#
# g:  0.25841361758751635
# error: -0.7415863824124836
# Peso Wk:  [ 0.40805635  0.06983519 -0.35860898]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 108
#
# g:  -0.759410844488525
# error: 0.24058915551147497
# Peso Wk:  [ 0.40809667  0.06993142 -0.35857342]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 109
#
# g:  0.44437885472193644
# error: -0.5556211452780635
# Peso Wk:  [ 0.40808359  0.06987253 -0.35862749]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 110
#
# g:  -0.9599855426488526
# error: 0.04001445735114739
# Peso Wk:  [ 0.40811531  0.06991369 -0.35862268]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 111
#
# g:  -0.017231480569514124
# error: -1.0172314805695142
# Peso Wk:  [ 0.40811302  0.06990697 -0.35863271]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 112
#
# g:  -0.6986800628750334
# error: 0.30131993712496663
# Peso Wk:  [ 0.408174    0.06992146 -0.35855756]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 113
#
# g:  -0.3253071537045131
# error: -1.3253071537045131
# Peso Wk:  [ 0.40815594  0.06982658 -0.35863182]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 114
#
# g:  0.5446725486137012
# error: -0.4553274513862988
# Peso Wk:  [ 0.40823936  0.06988531 -0.35844979]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 115
#
# g:  -0.5413561857991231
# error: 0.45864381420087685
# Peso Wk:  [ 0.40826801  0.0699384  -0.35845035]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 116
#
# g:  -0.23608484707548688
# error: -1.2360848470754868
# Peso Wk:  [ 0.40823915  0.06982683 -0.35854859]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 117
#
# g:  -0.1746264337694956
# error: -1.1746264337694956
# Peso Wk:  [ 0.40832084  0.06985041 -0.3583972 ]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 118
#
# g:  -0.20217316546627118
# error: 0.7978268345337288
# Peso Wk:  [ 0.40839846  0.06988283 -0.35826462]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 119
#
# g:  -0.6527403578328199
# error: 0.3472596421671801
# Peso Wk:  [ 0.40834574  0.06974811 -0.35838075]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 120
#
# g:  0.056149107369033
# error: 1.056149107369033
# Peso Wk:  [ 0.40832164  0.06968965 -0.35846348]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 121
#
# g:  -0.07714123821503494
# error: -1.077141238215035
# Peso Wk:  [ 0.40827034  0.06952476 -0.35854594]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 122
#
# g:  0.5091611178253368
# error: -0.4908388821746632
# Peso Wk:  [ 0.40832528  0.06959735 -0.35845748]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 123
#
# g:  0.3485872053475749
# error: -0.6514127946524251
# Peso Wk:  [ 0.40835031  0.06965028 -0.35845425]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 124
#
# g:  -0.25794468015400074
# error: 0.7420553198459993
# Peso Wk:  [ 0.40837357  0.06970883 -0.358439  ]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 125
#
# g:  0.3426719822298854
# error: -0.6573280177701146
# Peso Wk:  [ 0.40834708  0.06960169 -0.35850908]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 126
#
# g:  0.5051850063228146
# error: -0.4948149936771854
# Peso Wk:  [ 0.40837172  0.06962898 -0.35849927]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 127
#
# g:  -0.7318770865986507
# error: 0.2681229134013493
# Peso Wk:  [ 0.40839027  0.06965489 -0.35849925]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 128
#
# g:  -0.08608713604051232
# error: -1.0860871360405122
# Peso Wk:  [ 0.40838021  0.06963198 -0.35853567]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 129
#
# g:  0.1679518200031757
# error: -0.8320481799968242
# Peso Wk:  [ 0.40842296  0.06964108 -0.35847494]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 130
#
# g:  -0.5509960200779366
# error: 0.4490039799220634
# Peso Wk:  [ 0.40845572  0.06966637 -0.35844806]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 131
#
# g:  -0.5294138525030665
# error: 0.4705861474969335
# Peso Wk:  [ 0.40843804  0.06962162 -0.35850406]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 132
#
# g:  -0.5936087702963405
# error: 0.4063912297036595
# Peso Wk:  [ 0.40842508  0.06959407 -0.35854333]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 133
#
# g:  0.2750337117358256
# error: -0.7249662882641744
# Peso Wk:  [ 0.40841332  0.06953483 -0.35858769]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 134
#
# g:  -0.8663350959174407
# error: 0.13366490408255927
# Peso Wk:  [ 0.40843534  0.06955527 -0.35857553]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 135
#
# g:  -0.39868193515459927
# error: 0.6013180648454007
# Peso Wk:  [ 0.40843128  0.06953947 -0.35859303]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 136
#
# g:  0.18051581644824988
# error: 1.1805158164482499
# Peso Wk:  [ 0.40841849  0.06949532 -0.35863038]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 137
#
# g:  -0.3306157107523068
# error: 0.6693842892476932
# Peso Wk:  [ 0.40840092  0.06942291 -0.35865557]
#
# Error de entrenamiento:  20.679012345679013
# Error de Prueba:  25.0
# iteraciones = 138
#
# g:  0.34813201650495945
# error: 1.3481320165049595
# Peso Wk:  [ 0.40839046  0.06939933 -0.3586817 ]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 139
#
# g:  0.7452373561647564
# error: -0.2547626438352436
# Peso Wk:  [ 0.40837571  0.06935824 -0.35869212]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 140
#
# g:  0.47055672421571054
# error: -0.5294432757842895
# Peso Wk:  [ 0.40837864  0.06936493 -0.35869358]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 141
#
# g:  -0.7899578455500849
# error: 0.21004215444991514
# Peso Wk:  [ 0.4083829   0.06937505 -0.35869236]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 142
#
# g:  0.09003250132521684
# error: -0.9099674986747832
# Peso Wk:  [ 0.40838121  0.06937001 -0.35869898]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 143
#
# g:  -0.44877980215808577
# error: -1.4487798021580858
# Peso Wk:  [ 0.40838889  0.0693727  -0.35869164]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 144
#
# g:  0.5696979520257085
# error: -0.4303020479742915
# Peso Wk:  [ 0.40839745  0.06938894 -0.35866803]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 145
#
# g:  -0.07690668524833155
# error: -1.0769066852483316
# Peso Wk:  [ 0.4084      0.06938995 -0.35866898]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 146
#
# g:  -0.5732566160879161
# error: 0.4267433839120839
# Peso Wk:  [ 0.40840445  0.06938972 -0.358663  ]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 147
#
# g:  -0.3135393251474099
# error: 0.6864606748525901
# Peso Wk:  [ 0.40840269  0.06938344 -0.35866905]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 148
#
# g:  0.22170271126994312
# error: -0.7782972887300569
# Peso Wk:  [ 0.4084007   0.06937513 -0.35867465]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 149
#
# g:  -0.20556530410912466
# error: -1.2055653041091245
# Peso Wk:  [ 0.40840306  0.06937942 -0.35867259]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 150
#
# g:  -0.8394077921320299
# error: 0.16059220786797013
# Peso Wk:  [ 0.40840563  0.06938137 -0.35866782]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 151
#
# g:  0.44405571475504446
# error: -0.5559442852449555
# Peso Wk:  [ 0.40840529  0.06938045 -0.35866919]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 152
#
# g:  0.3658186739951738
# error: -0.6341813260048261
# Peso Wk:  [ 0.40840653  0.06938206 -0.358669  ]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 153
#
# g:  -0.43983617219446924
# error: 0.5601638278055308
# Peso Wk:  [ 0.40840752  0.069383   -0.3586687 ]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 154
#
# g:  -0.5737586891346728
# error: 0.42624131086532724
# Peso Wk:  [ 0.40840665  0.06937963 -0.35867143]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 155
#
# g:  -1.381233214366771
# error: -0.38123321436677093
# Peso Wk:  [ 0.40840595  0.06937702 -0.35867385]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 156
#
# g:  -1.0946907744128527
# error: -0.09469077441285267
# Peso Wk:  [ 0.4084066   0.06937981 -0.35867003]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 157
#
# g:  0.5263001248890478
# error: -0.47369987511095224
# Peso Wk:  [ 0.40840677  0.06938033 -0.35866924]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 158
#
# g:  -0.23626906692329375
# error: -1.2362690669232936
# Peso Wk:  [ 0.40840734  0.06938094 -0.35866931]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 159
#
# g:  0.25795275506761683
# error: -0.7420472449323832
# Peso Wk:  [ 0.40840838  0.06938124 -0.35866738]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 160
#
# g:  -0.6918219292891244
# error: 0.30817807071087555
# Peso Wk:  [ 0.40840901  0.06938203 -0.35866696]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 161
#
# g:  0.07269128470229741
# error: -0.9273087152977026
# Peso Wk:  [ 0.40840875  0.06938119 -0.35866792]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 162
#
# g:  0.07707756670645644
# error: -0.9229224332935435
# Peso Wk:  [ 0.40840957  0.06938227 -0.35866694]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 163
#
# g:  0.3016954539491257
# error: -0.6983045460508743
# Peso Wk:  [ 0.40841039  0.06938286 -0.35866607]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 164
#
# g:  0.37895639743457477
# error: -0.6210436025654252
# Peso Wk:  [ 0.40841101  0.06938464 -0.35866555]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 165
#
# g:  -0.7892760727121437
# error: 0.21072392728785627
# Peso Wk:  [ 0.40841156  0.06938487 -0.35866546]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 166
#
# g:  0.3574402969686512
# error: -0.6425597030313488
# Peso Wk:  [ 0.40841138  0.06938437 -0.35866618]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 167
#
# g:  0.041689786004781515
# error: -0.9583102139952184
# Peso Wk:  [ 0.40841198  0.06938532 -0.35866591]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 168
#
# g:  0.31579810686321097
# error: -0.684201893136789
# Peso Wk:  [ 0.4084126   0.06938617 -0.3586651 ]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 169
#
# g:  -0.38531406365328424
# error: 0.6146859363467158
# Peso Wk:  [ 0.40841305  0.06938649 -0.35866493]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 170
#
# g:  0.18550937624517783
# error: -0.8144906237548222
# Peso Wk:  [ 0.40841265  0.06938537 -0.35866603]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 171
#
# g:  -0.5152243233524816
# error: 0.4847756766475184
# Peso Wk:  [ 0.4084132   0.06938618 -0.35866553]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 172
#
# g:  -1.1322437659568567
# error: -0.13224376595685672
# Peso Wk:  [ 0.40841287  0.06938485 -0.35866664]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 173
#
# g:  -0.3929886376565729
# error: 0.6070113623434271
# Peso Wk:  [ 0.40841297  0.06938527 -0.35866615]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 174
#
# g:  -0.3808747513334486
# error: 0.6191252486665514
# Peso Wk:  [ 0.40841253  0.06938396 -0.35866738]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 175
#
# g:  -0.7898124622278797
# error: 0.2101875377721203
# Peso Wk:  [ 0.40841209  0.06938278 -0.35866859]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 176
#
# g:  0.17392536070382647
# error: -0.8260746392961735
# Peso Wk:  [ 0.40841193  0.06938231 -0.35866921]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 177
#
# g:  0.3824835758898684
# error: -0.6175164241101316
# Peso Wk:  [ 0.40841258  0.06938396 -0.35866846]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 178
#
# g:  -0.9452821029253844
# error: 0.05471789707461561
# Peso Wk:  [ 0.40841307  0.06938497 -0.35866823]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 179
#
# g:  -0.7612677100261618
# error: 0.23873228997383822
# Peso Wk:  [ 0.40841303  0.06938482 -0.35866842]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 180
#
# g:  0.15358379029299868
# error: -0.8464162097070014
# Peso Wk:  [ 0.4084129   0.06938448 -0.35866892]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 181
#
# g:  -1.1508746209177139
# error: -0.15087462091771386
# Peso Wk:  [ 0.40841339  0.06938581 -0.35866831]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 182
#
# g:  0.3574442740818105
# error: -0.6425557259181895
# Peso Wk:  [ 0.40841348  0.06938605 -0.35866788]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 183
#
# g:  0.18000886746876976
# error: 1.1800088674687697
# Peso Wk:  [ 0.40841374  0.06938646 -0.35866777]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 184
#
# g:  0.11495544163929222
# error: -0.8850445583607078
# Peso Wk:  [ 0.40841326  0.06938448 -0.35866846]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 185
#
# g:  0.3583188184804717
# error: -0.6416811815195282
# Peso Wk:  [ 0.40841364  0.06938533 -0.35866798]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 186
#
# g:  -0.20425736769802216
# error: -1.2042573676980222
# Peso Wk:  [ 0.40841391  0.06938532 -0.35866795]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 187
#
# g:  -0.3808668221110971
# error: 0.6191331778889029
# Peso Wk:  [ 0.40841427  0.06938609 -0.35866718]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 188
#
# g:  0.15705773827173514
# error: -0.8429422617282649
# Peso Wk:  [ 0.40841409  0.0693856  -0.35866768]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 189
#
# g:  -0.2371049467999985
# error: -1.2371049467999984
# Peso Wk:  [ 0.40841435  0.06938592 -0.35866743]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 190
#
# g:  -0.02103819934176232
# error: 0.9789618006582377
# Peso Wk:  [ 0.40841462  0.06938621 -0.35866689]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 191
#
# g:  0.7044678942283096
# error: -0.2955321057716904
# Peso Wk:  [ 0.40841441  0.06938559 -0.35866727]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 192
#
# g:  0.20157903861761706
# error: -0.7984209613823829
# Peso Wk:  [ 0.40841448  0.06938568 -0.35866731]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 193
#
# g:  -1.1228228881150486
# error: -0.1228228881150486
# Peso Wk:  [ 0.40841461  0.06938564 -0.35866724]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 194
#
# g:  -0.007951643428907251
# error: -1.0079516434289073
# Peso Wk:  [ 0.40841463  0.06938571 -0.35866714]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 195
#
# g:  0.3789603296182676
# error: -0.6210396703817325
# Peso Wk:  [ 0.40841474  0.0693857  -0.35866701]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 196
#
# g:  -0.7017033455136963
# error: 0.2982966544863037
# Peso Wk:  [ 0.40841481  0.06938573 -0.358667  ]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 197
#
# g:  -0.5147327704067481
# error: 0.48526722959325186
# Peso Wk:  [ 0.40841478  0.06938555 -0.35866714]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 198
#
# g:  0.4440718995236736
# error: -0.5559281004763263
# Peso Wk:  [ 0.40841474  0.06938541 -0.35866726]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 199
#
# g:  0.7044681085411828
# error: -0.2955318914588172
# Peso Wk:  [ 0.40841478  0.06938547 -0.35866726]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 200
#
# g:  -0.37248695121526143
# error: 0.6275130487847386
# Peso Wk:  [ 0.40841481  0.0693855  -0.35866727]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 201
#
# g:  -0.872005009012383
# error: 0.12799499098761702
# Peso Wk:  [ 0.40841476  0.06938522 -0.35866744]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 202
#
# g:  -0.20431580089049572
# error: 0.7956841991095043
# Peso Wk:  [ 0.40841475  0.06938519 -0.35866749]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 203
#
# g:  -1.0946542693388785
# error: -0.09465426933887855
# Peso Wk:  [ 0.4084147   0.06938506 -0.35866759]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 204
#
# g:  0.2217409306718935
# error: -0.7782590693281065
# Peso Wk:  [ 0.4084147   0.06938508 -0.35866756]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 205
#
# g:  -0.8336082590319254
# error: 0.16639174096807463
# Peso Wk:  [ 0.40841474  0.06938515 -0.35866753]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 206
#
# g:  -0.2990324232078765
# error: 0.7009675767921235
# Peso Wk:  [ 0.40841473  0.06938513 -0.35866756]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 207
#
# g:  0.06791361817392555
# error: -0.9320863818260745
# Peso Wk:  [ 0.40841471  0.06938508 -0.35866762]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 208
#
# g:  -0.03422116310244172
# error: 0.9657788368975583
# Peso Wk:  [ 0.40841474  0.06938513 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 209
#
# g:  -0.36513333806809434
# error: 0.6348666619319057
# Peso Wk:  [ 0.40841471  0.06938502 -0.35866764]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 210
#
# g:  -0.5630125807024566
# error: -1.5630125807024566
# Peso Wk:  [ 0.40841469  0.06938494 -0.3586677 ]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 211
#
# g:  -0.31873418566612677
# error: 0.6812658143338732
# Peso Wk:  [ 0.40841474  0.06938504 -0.35866753]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 212
#
# g:  0.04168982515559638
# error: -0.9583101748444036
# Peso Wk:  [ 0.40841472  0.06938493 -0.3586676 ]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 213
#
# g:  -0.9845497992884034
# error: 0.01545020071159664
# Peso Wk:  [ 0.40841475  0.06938498 -0.35866755]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 214
#
# g:  -0.833608718858478
# error: 0.16639128114152202
# Peso Wk:  [ 0.40841475  0.06938498 -0.35866755]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 215
#
# g:  -0.8347473073433385
# error: 0.16525269265666154
# Peso Wk:  [ 0.40841475  0.06938497 -0.35866757]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 216
#
# g:  0.341713234589445
# error: -0.658286765410555
# Peso Wk:  [ 0.40841474  0.06938495 -0.35866759]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 217
#
# g:  -0.20425648259573748
# error: -1.2042564825957376
# Peso Wk:  [ 0.40841476  0.06938497 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 218
#
# g:  -0.23625713404700965
# error: -1.2362571340470097
# Peso Wk:  [ 0.40841479  0.06938503 -0.35866753]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 219
#
# g:  -0.38086990618809313
# error: 0.6191300938119069
# Peso Wk:  [ 0.40841482  0.06938503 -0.35866748]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 220
#
# g:  0.5087745345574843
# error: -0.49122546544251566
# Peso Wk:  [ 0.4084148   0.069385   -0.35866752]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 221
#
# g:  0.3861030645941116
# error: -0.6138969354058884
# Peso Wk:  [ 0.40841481  0.06938502 -0.35866752]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 222
#
# g:  0.3567506249810716
# error: -0.6432493750189284
# Peso Wk:  [ 0.40841482  0.06938503 -0.35866751]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 223
#
# g:  -0.8029957714421023
# error: 0.19700422855789768
# Peso Wk:  [ 0.40841483  0.06938505 -0.35866751]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 224
#
# g:  -0.5174180715113674
# error: 0.48258192848863257
# Peso Wk:  [ 0.40841483  0.06938504 -0.35866752]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 225
#
# g:  -0.9845494460040656
# error: 0.015450553995934424
# Peso Wk:  [ 0.40841482  0.06938503 -0.35866753]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 226
#
# g:  -0.054110277083110336
# error: 0.9458897229168897
# Peso Wk:  [ 0.40841482  0.06938503 -0.35866753]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 227
#
# g:  -0.8720060221422725
# error: 0.12799397785772748
# Peso Wk:  [ 0.40841482  0.06938501 -0.35866754]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 228
#
# g:  0.4646500354087707
# error: -0.5353499645912293
# Peso Wk:  [ 0.40841482  0.06938501 -0.35866754]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 229
#
# g:  -0.595140936727689
# error: 0.404859063272311
# Peso Wk:  [ 0.40841482  0.06938502 -0.35866754]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 230
#
# g:  -0.16027269572531322
# error: 0.8397273042746868
# Peso Wk:  [ 0.40841482  0.069385   -0.35866755]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 231
#
# g:  0.30058453466126955
# error: -0.6994154653387304
# Peso Wk:  [ 0.40841482  0.06938499 -0.35866756]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 232
#
# g:  -0.12000393347308602
# error: 0.879996066526914
# Peso Wk:  [ 0.40841482  0.069385   -0.35866756]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 233
#
# g:  -0.44056425325492454
# error: 0.5594357467450755
# Peso Wk:  [ 0.40841481  0.06938498 -0.35866757]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 234
#
# g:  -0.3187345043755361
# error: 0.6812654956244639
# Peso Wk:  [ 0.40841481  0.06938498 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 235
#
# g:  -0.9614374718609486
# error: 0.038562528139051366
# Peso Wk:  [ 0.40841481  0.06938497 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 236
#
# g:  -0.2745106886443649
# error: 0.7254893113556351
# Peso Wk:  [ 0.40841481  0.06938497 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 237
#
# g:  0.22303334360427107
# error: -0.7769666563957289
# Peso Wk:  [ 0.40841481  0.06938496 -0.35866759]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 238
#
# g:  0.15358865457674165
# error: -0.8464113454232584
# Peso Wk:  [ 0.40841481  0.06938497 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 239
#
# g:  0.017916947729080812
# error: -0.9820830522709192
# Peso Wk:  [ 0.40841481  0.06938497 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 240
#
# g:  -0.7619420222335671
# error: 0.2380579777664329
# Peso Wk:  [ 0.40841481  0.06938497 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 241
#
# g:  -0.007951913074062122
# error: -1.0079519130740622
# Peso Wk:  [ 0.40841481  0.06938497 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 242
#
# g:  0.34391200153315105
# error: -0.656087998466849
# Peso Wk:  [ 0.40841481  0.06938497 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 243
#
# g:  -0.38532387815275904
# error: 0.614676121847241
# Peso Wk:  [ 0.40841481  0.06938497 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 244
#
# g:  -0.7017097397131781
# error: 0.29829026028682193
# Peso Wk:  [ 0.40841481  0.06938497 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 245
#
# g:  0.70654677422804
# error: -0.29345322577196
# Peso Wk:  [ 0.40841481  0.06938497 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 246
#
# g:  -0.013292801733098991
# error: -1.0132928017330989
# Peso Wk:  [ 0.40841481  0.06938497 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 247
#
# g:  -0.18611049807213376
# error: -1.1861104980721338
# Peso Wk:  [ 0.40841481  0.06938497 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 248
#
# g:  0.36583014600101305
# error: -0.634169853998987
# Peso Wk:  [ 0.40841482  0.06938497 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 249
#
# g:  0.3157984606072327
# error: -0.6842015393927673
# Peso Wk:  [ 0.40841482  0.06938497 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 250
#
# g:  -0.034057010665354104
# error: -1.0340570106653542
# Peso Wk:  [ 0.40841482  0.06938497 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 251
#
# g:  0.17751121041377
# error: -0.8224887895862301
# Peso Wk:  [ 0.40841482  0.06938497 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 252
#
# g:  -0.30167143034901345
# error: 0.6983285696509866
# Peso Wk:  [ 0.40841482  0.06938497 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 253
#
# g:  -0.17518864108271165
# error: -1.1751886410827117
# Peso Wk:  [ 0.40841482  0.06938497 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 254
#
# g:  -1.094689130686653
# error: -0.09468913068665308
# Peso Wk:  [ 0.40841482  0.06938497 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 255
#
# g:  -0.9342667326478864
# error: 0.0657332673521136
# Peso Wk:  [ 0.40841482  0.06938497 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 256
#
# g:  -0.1914772952891748
# error: 0.8085227047108252
# Peso Wk:  [ 0.40841482  0.06938497 -0.35866758]
#
# ...
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 915
#
# g:  -0.1760813958267684
# error: 0.8239186041732316
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 916
#
# g:  -0.5540625793630458
# error: 0.4459374206369542
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 917
#
# g:  0.5236241319092129
# error: -0.47637586809078714
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 918
#
# g:  -0.802996385001703
# error: 0.197003614998297
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 919
#
# g:  0.1535886611042887
# error: -0.8464113388957113
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 920
#
# g:  -0.16031134517844825
# error: 0.8396886548215517
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 921
#
# g:  -0.1861105015262634
# error: -1.1861105015262634
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 922
#
# g:  0.5439252671958025
# error: -0.4560747328041975
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 923
#
# g:  -0.8587515265047152
# error: 0.1412484734952848
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 924
#
# g:  -0.7897992905732865
# error: 0.21020070942671354
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 925
#
# g:  0.027547353090803972
# error: -0.9724526469091961
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 926
#
# g:  -0.3720958573791906
# error: 0.6279041426208094
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 927
#
# g:  -0.6173662459005093
# error: 0.38263375409949074
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 928
#
# g:  -0.36513328052835115
# error: 0.6348667194716489
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 929
#
# g:  -0.6918089997310687
# error: 0.3081910002689313
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 930
#
# g:  -0.6173662459005093
# error: 0.38263375409949074
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 931
#
# g:  -0.01611060810002274
# error: -1.0161106081000226
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 932
#
# g:  0.2897548725626043
# error: -0.7102451274373958
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 933
#
# g:  -0.31049834264172393
# error: 0.6895016573582761
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 934
#
# g:  -0.6465937387447318
# error: -1.6465937387447318
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 935
#
# g:  -0.039209403877007554
# error: 0.9607905961229924
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 936
#
# g:  -0.18311295560049634
# error: 0.8168870443995037
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 937
#
# g:  -1.008763099813367
# error: -0.008763099813366981
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 938
#
# g:  -0.8155863838682371
# error: 0.18441361613176288
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 939
#
# g:  -0.2598178911273674
# error: 0.7401821088726326
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 940
#
# g:  -0.0433712783208578
# error: -1.0433712783208577
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 941
#
# g:  0.03563761609994753
# error: -0.9643623839000525
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 942
#
# g:  -0.9614374672453814
# error: 0.03856253275461863
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 943
#
# g:  -0.01611060810002274
# error: -1.0161106081000226
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 944
#
# g:  -0.00012627047315250106
# error: 0.9998737295268475
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 945
#
# g:  -0.4762114545745233
# error: 0.5237885454254767
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 946
#
# g:  0.6316389308691766
# error: -0.36836106913082345
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 947
#
# g:  -0.399449644796553
# error: 0.600550355203447
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 948
#
# g:  -0.496495746961666
# error: 0.503504253038334
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 949
#
# g:  -0.9962464852415667
# error: 0.0037535147584333295
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 950
#
# g:  -1.1521581274340258
# error: -0.1521581274340258
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 951
#
# g:  -0.23358380916163513
# error: 0.7664161908383649
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 952
#
# g:  -1.1302029132490325
# error: -0.13020291324903255
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 953
#
# g:  -0.3307173287834342
# error: 0.6692826712165658
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 954
#
# g:  -0.1760813958267684
# error: 0.8239186041732316
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 955
#
# g:  0.10009966768543693
# error: -0.8999003323145631
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 956
#
# g:  0.029123925655009986
# error: 1.02912392565501
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 957
#
# g:  -0.17140972532185222
# error: -1.1714097253218523
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 958
#
# g:  0.2579636937280494
# error: -0.7420363062719506
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 959
#
# g:  -0.7094644221691659
# error: 0.29053557783083406
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 960
#
# g:  -0.21138617499810208
# error: -1.211386174998102
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 961
#
# g:  -0.6918089997310687
# error: 0.3081910002689313
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 962
#
# g:  0.566849534098276
# error: -0.433150465901724
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 963
#
# g:  0.1535886611042887
# error: -0.8464113388957113
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 964
#
# g:  0.18000404585460672
# error: 1.1800040458546066
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 965
#
# g:  -0.6863454349453761
# error: 0.31365456505462386
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 966
#
# g:  -0.1132153917120205
# error: -1.1132153917120204
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 967
#
# g:  0.35675045057809773
# error: -0.6432495494219023
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 968
#
# g:  0.2495117723833944
# error: -0.7504882276166056
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 969
#
# g:  -1.3811542443108693
# error: -0.3811542443108693
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 970
#
# g:  0.16993088913137872
# error: -0.8300691108686213
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 971
#
# g:  0.23760847945826533
# error: -0.7623915205417346
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 972
#
# g:  0.7975779630777351
# error: -0.2024220369222649
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 973
#
# g:  -0.3963517670816066
# error: 0.6036482329183934
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 974
#
# g:  0.23513408833213345
# error: 1.2351340883321336
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 975
#
# g:  0.526312969323426
# error: -0.47368703067657403
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 976
#
# g:  -0.15660604286290247
# error: -1.1566060428629026
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 977
#
# g:  0.7044676849464855
# error: -0.2955323150535145
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 978
#
# g:  -0.4078240436057483
# error: 0.5921759563942517
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 979
#
# g:  0.16993088913137872
# error: -0.8300691108686213
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 980
#
# g:  -0.034221686164039644
# error: 0.9657783138359604
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 981
#
# g:  0.35832007593337883
# error: -0.6416799240666211
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 982
#
# g:  -0.039209403877007554
# error: 0.9607905961229924
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 983
#
# g:  -0.03492855173609466
# error: 0.9650714482639053
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 984
#
# g:  0.27671075909839726
# error: -0.7232892409016027
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 985
#
# g:  -0.6449597414110758
# error: 0.3550402585889242
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 986
#
# g:  -0.5174185552528255
# error: 0.48258144474717446
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 987
#
# g:  0.025621995500624273
# error: -0.9743780044993757
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 988
#
# g:  -0.5218278843920401
# error: -1.52182788439204
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 989
#
# g:  -0.4138777318244209
# error: 0.5861222681755791
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 990
#
# g:  -0.17140972532185222
# error: -1.1714097253218523
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 991
#
# g:  -0.5740038656154524
# error: 0.42599613438454764
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 992
#
# g:  0.9161730738087372
# error: -0.08382692619126275
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 993
#
# g:  -0.44418236523213994
# error: 0.5558176347678601
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 994
#
# g:  -0.4230655071687488
# error: 0.5769344928312512
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 995
#
# g:  -0.5737173318219208
# error: 0.42628266817807925
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 996
#
# g:  -0.7094644221691659
# error: 0.29053557783083406
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 997
#
# g:  0.10238551627077264
# error: -0.8976144837292274
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 998
#
# g:  -0.14090538249720352
# error: 0.8590946175027965
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0
# iteraciones = 999
#
# g:  -0.8246762935552966
# error: 0.1753237064447034
# Peso Wk:  [ 0.40841482  0.06938496 -0.35866758]
#
# Error de entrenamiento:  20.37037037037037
# Error de Prueba:  25.0

# %%
##################  Probando datos de Validacion  ###########
error_val = 0
for i in range (D_val):
    Y = Y_val[i][0]
    g = np.dot(np.transpose(Wk),X_val[i])
    
    if g < 0:                # se establece un umbral para poder hacer clasificacion con el algoritmo LMS
        g = -1
    else:
        g = 1
    
    if(g != Y):
        error_val = error_val + 1

err_porc = 100*error_val/D_val
print("Error total de validacion: ", err_porc)
# Out:
# Error total de validacion:  19.444444444444443

# %%
plt.figure(figsize=(14,8))
plt.plot(error_ent, 'b+', label = "Error de entrenamiento pequeño")
plt.legend()
plt.xlabel("Iteraciones")
plt.ylabel("Error")
plt.grid()

# %%
plt.figure(figsize=(14,8))
plt.plot(V_errorEnt , 'g' ,label="Error Entrenamiento")
plt.plot(V_errorPru, 'r' , label ="Error Prueba")
plt.legend()
plt.xlabel('Iteraciones')
plt.ylabel('Error (%)')
plt.grid()
